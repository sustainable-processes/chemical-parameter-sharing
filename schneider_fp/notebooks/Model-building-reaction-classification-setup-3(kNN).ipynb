# %% [markdown]
# ### Learning reaction types using different ML methods (kNN) and more local difference fingerprints (AP3, MG2, TT)

# %% [markdown]
# Goal: generate a baseline ML model for our FPs

# %%
import cPickle,gzip
from collections import defaultdict
import random
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
import utilsFunctions
# Out:
# /usr/prog/python/2.7.5/lib/python2.7/site-packages/nose/plugins/manager.py:418: UserWarning: Module argparse was already imported from /usr/prog/python/2.7.5/lib/python2.7/argparse.pyc, but /usr/prog/python/2.7.5/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Choose some larger text size in the plots

# %%
rcParams.update({'font.size': 14})

# %%
dataDir = "../data/"
reaction_types = cPickle.load(file(dataDir+"reactionTypes_training_test_set_patent_data.pkl"))
names_rTypes = cPickle.load(file(dataDir+"names_rTypes_classes_superclasses_training_test_set_patent_data.pkl"))

# %% [markdown]
# Load the different FPs (AP3, MG2, TT)

# %%
infile = gzip.open(dataDir+"transformationFPs_test_set_patent_data.pkl.gz", 'rb')

lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_AP3,fp_MG2,fp_TT = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_AP3,fp_MG2,fp_TT])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %% [markdown]
# Split the FPs in training (20 %) and test data (80 %) per recation type (200, 800)

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=2048
#fpsz=4096
trainFps_fp_AP3=[]
trainFps_fp_MG2=[]
trainFps_fp_TT=[]
trainActs=[]
testFps_fp_AP3=[]
testFps_fp_MG2=[]
testFps_fp_TT=[]
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        trainFps_fp_AP3 += [utilsFunctions.fpToNP(fps[x][3],fpsz)]
        trainFps_fp_MG2 += [utilsFunctions.fpToNP(fps[x][4],fpsz)]
        trainFps_fp_TT += [utilsFunctions.fpToNP(fps[x][5],fpsz)]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        testFps_fp_AP3 += [utilsFunctions.fpToNP(fps[x][3],fpsz)]
        testFps_fp_MG2 += [utilsFunctions.fpToNP(fps[x][4],fpsz)]
        testFps_fp_TT += [utilsFunctions.fpToNP(fps[x][5],fpsz)]
    testActs += [i]*nTest
# Out:
# building fp collection

# %% [markdown]
# Build the kNN classifiers with k=3

# %%
kNN_cls_AP3 = KNeighborsClassifier(n_neighbors=3)
result_kNN_fp_AP3 = kNN_cls_AP3.fit(trainFps_fp_AP3,trainActs)
kNN_cls_MG2 = KNeighborsClassifier(n_neighbors=3)
result_kNN_fp_MG2 = kNN_cls_MG2.fit(trainFps_fp_MG2,trainActs)
kNN_cls_TT = KNeighborsClassifier(n_neighbors=3)
result_kNN_fp_TT = kNN_cls_TT.fit(trainFps_fp_TT,trainActs)

# %% [markdown]
# Evaluate the models

# %%
cmat_fp_AP3 = utilsFunctions.evaluateModel(result_kNN_fp_AP3, testFps_fp_AP3, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9213  0.9547  0.9377     1.2.1 Aldehyde reductive amination
#  1  0.9850  0.8464  0.9105     1.2.4 Eschweiler-Clarke methylation
#  2  0.9738  0.9861  0.9799     1.2.5 Ketone reductive amination
#  3  0.9487  0.8972  0.9222     1.3.6 Bromo N-arylation
#  4  0.9300  0.9084  0.9191     1.3.7 Chloro N-arylation
#  5  0.9712  0.9305  0.9505     1.3.8 Fluoro N-arylation
#  6  0.8050  0.7825  0.7936     1.6.2 Bromo N-alkylation
#  7  0.7150  0.8487  0.7761     1.6.4 Chloro N-alkylation
#  8  0.7388  0.7655  0.7519     1.6.8 Iodo N-alkylation
#  9  0.9550  0.8489  0.8988     1.7.4 Hydroxy to methoxy
# 10  0.9513  0.5936  0.7310     1.7.6 Methyl esterification
# 11  0.8938  0.8667  0.8800     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.7850  0.9486  0.8591     1.7.9 Williamson ether synthesis
# 13  0.9712  0.9949  0.9829     1.8.5 Thioether synthesis
# 14  0.9213  0.9010  0.9110    10.1.1 Bromination
# 15  0.8888  0.9556  0.9210    10.1.2 Chlorination
# 16  0.9513  0.9326  0.9418    10.1.5 Wohl-Ziegler bromination
# 17  0.9712  0.9885  0.9798    10.2.1 Nitration
# 18  0.7100  0.8000  0.7523    10.4.2 Methylation
# 19  0.8912  0.8498  0.8700     2.1.1 Amide Schotten-Baumann
# 20  0.8862  0.9268  0.9061     2.1.2 Carboxylic acid + amine reaction
# 21  0.9237  0.9585  0.9408     2.1.7 N-acetylation
# 22  0.9862  0.9962  0.9912     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9875  1.0000  0.9937     2.3.1 Isocyanate + amine reaction
# 24  0.9287  0.8751  0.9012     2.6.1 Ester Schotten-Baumann
# 25  0.4412  0.8445  0.5796     2.6.3 Fischer-Speier esterification
# 26  0.9938  1.0000  0.9969     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5663  0.5399  0.5528     3.1.1 Bromo Suzuki coupling
# 28  0.5150  0.5553  0.5344     3.1.5 Bromo Suzuki-type coupling
# 29  0.9500  0.9794  0.9645     3.1.6 Chloro Suzuki-type coupling
# 30  0.9888  0.9937  0.9912     3.3.1 Sonogashira coupling
# 31  0.9513  0.9731  0.9621     3.4.1 Stille reaction
# 32  0.9537  0.9961  0.9745     5.1.1 N-Boc protection
# 33  0.9975  0.9938  0.9956     6.1.1 N-Boc deprotection
# 34  1.0000  0.9889  0.9944     6.1.3 N-Cbz deprotection
# 35  0.9925  0.9876  0.9900     6.1.5 N-Bn deprotection
# 36  0.9938  0.9815  0.9876     6.2.1 CO2H-Et deprotection
# 37  0.9938  0.9719  0.9827     6.2.2 CO2H-Me deprotection
# 38  0.9975  0.9901  0.9938     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.9864  0.9919     6.3.1 O-Bn deprotection
# 40  0.9812  0.9849  0.9831     6.3.7 Methoxy to hydroxy
# 41  0.9850  0.9975  0.9912     7.1.1 Nitro to amino
# 42  0.9825  0.9813  0.9819     7.2.1 Amide to amine reduction
# 43  0.9988  0.9864  0.9925     7.3.1 Nitrile reduction
# 44  0.9875  0.9646  0.9759     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9950  0.9827  0.9888     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9950  1.0000  0.9975     8.1.5 Alcohol to ketone oxidation
# 47  0.9888  1.0000  0.9943     8.2.1 Sulfanyl to sulfinyl
# 48  0.9337  0.9651  0.9492     9.1.6 Hydroxy to chloro
# 49  0.9725  0.9185  0.9447     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.91    0.92    0.92

# %%
utilsFunctions.labelled_cmat(cmat_fp_AP3,rtypes,figsize=(16,12),labelExtras=names_rTypes, xlabel=False)

# %%
cmat_fp_MG2 = utilsFunctions.evaluateModel(result_kNN_fp_MG2, testFps_fp_MG2, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.8325  0.9610  0.8922     1.2.1 Aldehyde reductive amination
#  1  0.6837  0.7141  0.6986     1.2.4 Eschweiler-Clarke methylation
#  2  0.8888  0.9916  0.9374     1.2.5 Ketone reductive amination
#  3  0.7125  0.7766  0.7432     1.3.6 Bromo N-arylation
#  4  0.7462  0.8361  0.7886     1.3.7 Chloro N-arylation
#  5  0.7825  0.8552  0.8172     1.3.8 Fluoro N-arylation
#  6  0.4700  0.7162  0.5675     1.6.2 Bromo N-alkylation
#  7  0.5112  0.7239  0.5993     1.6.4 Chloro N-alkylation
#  8  0.5188  0.7815  0.6236     1.6.8 Iodo N-alkylation
#  9  0.9187  0.7477  0.8245     1.7.4 Hydroxy to methoxy
# 10  0.8912  0.1432  0.2467     1.7.6 Methyl esterification
# 11  0.7425  0.8710  0.8016     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.6038  0.9699  0.7442     1.7.9 Williamson ether synthesis
# 13  0.7450  0.9917  0.8508     1.8.5 Thioether synthesis
# 14  0.5700  0.8941  0.6962    10.1.1 Bromination
# 15  0.5613  0.9182  0.6967    10.1.2 Chlorination
# 16  0.9163  0.9361  0.9261    10.1.5 Wohl-Ziegler bromination
# 17  0.9012  0.9487  0.9244    10.2.1 Nitration
# 18  0.3500  0.6880  0.4640    10.4.2 Methylation
# 19  0.7013  0.8386  0.7638     2.1.1 Amide Schotten-Baumann
# 20  0.6600  0.9103  0.7652     2.1.2 Carboxylic acid + amine reaction
# 21  0.9075  0.9784  0.9416     2.1.7 N-acetylation
# 22  0.8450  0.9535  0.8960     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9888  1.0000  0.9943     2.3.1 Isocyanate + amine reaction
# 24  0.8700  0.9146  0.8917     2.6.1 Ester Schotten-Baumann
# 25  0.5275  0.7496  0.6192     2.6.3 Fischer-Speier esterification
# 26  0.9725  0.9737  0.9731     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6188  0.5386  0.5759     3.1.1 Bromo Suzuki coupling
# 28  0.4650  0.5767  0.5149     3.1.5 Bromo Suzuki-type coupling
# 29  0.9113  0.9643  0.9370     3.1.6 Chloro Suzuki-type coupling
# 30  0.9275  0.9973  0.9611     3.3.1 Sonogashira coupling
# 31  0.8950  0.9849  0.9378     3.4.1 Stille reaction
# 32  0.9413  0.9960  0.9679     5.1.1 N-Boc protection
# 33  0.9925  0.9950  0.9937     6.1.1 N-Boc deprotection
# 34  0.9962  0.9913  0.9938     6.1.3 N-Cbz deprotection
# 35  0.9862  0.9937  0.9900     6.1.5 N-Bn deprotection
# 36  0.9938  0.9648  0.9791     6.2.1 CO2H-Et deprotection
# 37  0.9925  0.9790  0.9857     6.2.2 CO2H-Me deprotection
# 38  0.9975  0.9803  0.9888     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.9591  0.9779     6.3.1 O-Bn deprotection
# 40  0.9850  0.9912  0.9881     6.3.7 Methoxy to hydroxy
# 41  0.9788  0.9937  0.9861     7.1.1 Nitro to amino
# 42  0.6675  0.9889  0.7970     7.2.1 Amide to amine reduction
# 43  0.9988  0.9889  0.9938     7.3.1 Nitrile reduction
# 44  0.9812  0.9632  0.9721     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9888  0.9925  0.9906     8.1.4 Alcohol to aldehyde oxidation
# 46  0.7588  1.0000  0.8628     8.1.5 Alcohol to ketone oxidation
# 47  0.8100  1.0000  0.8950     8.2.1 Sulfanyl to sulfinyl
# 48  0.9200  0.9534  0.9364     9.1.6 Hydroxy to chloro
# 49  0.9800  0.8503  0.9106     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.81    0.89    0.85

# %%
utilsFunctions.labelled_cmat(cmat_fp_MG2,rtypes,figsize=(16,12),labelExtras=names_rTypes)

# %%
cmat_fp_TT = utilsFunctions.evaluateModel(result_kNN_fp_TT, testFps_fp_TT, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.7375  0.8538  0.7914     1.2.1 Aldehyde reductive amination
#  1  0.8875  0.6068  0.7208     1.2.4 Eschweiler-Clarke methylation
#  2  0.8888  0.9673  0.9264     1.2.5 Ketone reductive amination
#  3  0.7125  0.7028  0.7076     1.3.6 Bromo N-arylation
#  4  0.7525  0.7728  0.7625     1.3.7 Chloro N-arylation
#  5  0.7512  0.8222  0.7851     1.3.8 Fluoro N-arylation
#  6  0.4725  0.5087  0.4900     1.6.2 Bromo N-alkylation
#  7  0.4200  0.7179  0.5300     1.6.4 Chloro N-alkylation
#  8  0.5212  0.5666  0.5430     1.6.8 Iodo N-alkylation
#  9  0.8538  0.7182  0.7801     1.7.4 Hydroxy to methoxy
# 10  0.9788  0.5707  0.7210     1.7.6 Methyl esterification
# 11  0.7375  0.7516  0.7445     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.5887  0.8920  0.7093     1.7.9 Williamson ether synthesis
# 13  0.7925  0.9799  0.8763     1.8.5 Thioether synthesis
# 14  0.7275  0.7221  0.7248    10.1.1 Bromination
# 15  0.6613  0.8076  0.7271    10.1.2 Chlorination
# 16  0.8862  0.9125  0.8992    10.1.5 Wohl-Ziegler bromination
# 17  0.9263  0.9674  0.9464    10.2.1 Nitration
# 18  0.3638  0.6962  0.4778    10.4.2 Methylation
# 19  0.6462  0.6794  0.6624     2.1.1 Amide Schotten-Baumann
# 20  0.6438  0.8175  0.7203     2.1.2 Carboxylic acid + amine reaction
# 21  0.8850  0.9377  0.9106     2.1.7 N-acetylation
# 22  0.9450  0.9767  0.9606     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9150  0.9973  0.9544     2.3.1 Isocyanate + amine reaction
# 24  0.8237  0.2134  0.3390     2.6.1 Ester Schotten-Baumann
# 25  0.3550  0.7802  0.4880     2.6.3 Fischer-Speier esterification
# 26  0.9762  1.0000  0.9880     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6388  0.4923  0.5560     3.1.1 Bromo Suzuki coupling
# 28  0.3638  0.5096  0.4245     3.1.5 Bromo Suzuki-type coupling
# 29  0.8375  0.8747  0.8557     3.1.6 Chloro Suzuki-type coupling
# 30  0.9475  0.9987  0.9724     3.3.1 Sonogashira coupling
# 31  0.8413  0.9725  0.9021     3.4.1 Stille reaction
# 32  0.9275  0.9987  0.9618     5.1.1 N-Boc protection
# 33  0.9700  0.9936  0.9817     6.1.1 N-Boc deprotection
# 34  0.9663  0.9936  0.9797     6.1.3 N-Cbz deprotection
# 35  0.9912  0.9912  0.9912     6.1.5 N-Bn deprotection
# 36  0.9938  0.9625  0.9779     6.2.1 CO2H-Et deprotection
# 37  0.9650  0.9158  0.9397     6.2.2 CO2H-Me deprotection
# 38  0.9975  0.9696  0.9834     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.9603  0.9785     6.3.1 O-Bn deprotection
# 40  0.9100  0.9918  0.9492     6.3.7 Methoxy to hydroxy
# 41  0.9500  0.9845  0.9669     7.1.1 Nitro to amino
# 42  0.8550  0.9856  0.9157     7.2.1 Amide to amine reduction
# 43  0.9075  0.9851  0.9447     7.3.1 Nitrile reduction
# 44  0.9150  0.9445  0.9295     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.8662  0.9706  0.9155     8.1.4 Alcohol to aldehyde oxidation
# 46  0.8013  0.9907  0.8860     8.1.5 Alcohol to ketone oxidation
# 47  0.9213  0.9973  0.9578     8.2.1 Sulfanyl to sulfinyl
# 48  0.7450  0.9660  0.8412     9.1.6 Hydroxy to chloro
# 49  0.9175  0.8495  0.8822     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.80    0.84    0.82

# %%
utilsFunctions.labelled_cmat(cmat_fp_TT,rtypes,figsize=(16,12),labelExtras=names_rTypes)

# %% [markdown]
# Build the kNN classifiers with k=30

# %%
kNN_cls_AP3 = KNeighborsClassifier(n_neighbors=30)
result_kNN_fp_AP3 = kNN_cls_AP3.fit(trainFps_fp_AP3,trainActs)
kNN_cls_MG2 = KNeighborsClassifier(n_neighbors=30)
result_kNN_fp_MG2 = kNN_cls_MG2.fit(trainFps_fp_MG2,trainActs)
kNN_cls_TT = KNeighborsClassifier(n_neighbors=30)
result_kNN_fp_TT = kNN_cls_TT.fit(trainFps_fp_TT,trainActs)

# %% [markdown]
# Evaluate the models

# %%
cmat_fp_AP3 = utilsFunctions.evaluateModel(result_kNN_fp_AP3, testFps_fp_AP3, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.8337  0.9896  0.9050     1.2.1 Aldehyde reductive amination
#  1  0.9788  0.6773  0.8006     1.2.4 Eschweiler-Clarke methylation
#  2  0.9000  0.9931  0.9443     1.2.5 Ketone reductive amination
#  3  0.9075  0.9109  0.9092     1.3.6 Bromo N-arylation
#  4  0.9263  0.8864  0.9059     1.3.7 Chloro N-arylation
#  5  0.8875  0.9621  0.9233     1.3.8 Fluoro N-arylation
#  6  0.6663  0.8039  0.7286     1.6.2 Bromo N-alkylation
#  7  0.6162  0.8189  0.7033     1.6.4 Chloro N-alkylation
#  8  0.6175  0.6309  0.6241     1.6.8 Iodo N-alkylation
#  9  0.8662  0.7674  0.8139     1.7.4 Hydroxy to methoxy
# 10  0.9300  0.5243  0.6706     1.7.6 Methyl esterification
# 11  0.8263  0.7598  0.7916     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.4525  0.9258  0.6079     1.7.9 Williamson ether synthesis
# 13  0.9600  0.9505  0.9552     1.8.5 Thioether synthesis
# 14  0.8650  0.8793  0.8721    10.1.1 Bromination
# 15  0.8400  0.9586  0.8954    10.1.2 Chlorination
# 16  0.9688  0.8554  0.9086    10.1.5 Wohl-Ziegler bromination
# 17  0.9613  0.9948  0.9777    10.2.1 Nitration
# 18  0.3325  0.7368  0.4582    10.4.2 Methylation
# 19  0.7875  0.7258  0.7554     2.1.1 Amide Schotten-Baumann
# 20  0.7937  0.6947  0.7410     2.1.2 Carboxylic acid + amine reaction
# 21  0.8988  0.9677  0.9320     2.1.7 N-acetylation
# 22  0.9738  0.9873  0.9805     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9250  0.9987  0.9604     2.3.1 Isocyanate + amine reaction
# 24  0.8675  0.8089  0.8372     2.6.1 Ester Schotten-Baumann
# 25  0.5088  0.6262  0.5614     2.6.3 Fischer-Speier esterification
# 26  0.9550  0.9961  0.9751     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5450  0.4994  0.5212     3.1.1 Bromo Suzuki coupling
# 28  0.4062  0.5390  0.4633     3.1.5 Bromo Suzuki-type coupling
# 29  0.9325  0.9086  0.9204     3.1.6 Chloro Suzuki-type coupling
# 30  0.9962  0.9876  0.9919     3.3.1 Sonogashira coupling
# 31  0.8688  0.9508  0.9079     3.4.1 Stille reaction
# 32  0.8900  0.9986  0.9412     5.1.1 N-Boc protection
# 33  0.9938  0.9938  0.9938     6.1.1 N-Boc deprotection
# 34  0.9988  0.9312  0.9638     6.1.3 N-Cbz deprotection
# 35  0.9825  0.9752  0.9788     6.1.5 N-Bn deprotection
# 36  0.9938  0.9544  0.9737     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.8825  0.9354     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9828  0.9907     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.9279  0.9614     6.3.1 O-Bn deprotection
# 40  0.9113  0.9825  0.9455     6.3.7 Methoxy to hydroxy
# 41  0.9788  0.9962  0.9874     7.1.1 Nitro to amino
# 42  0.8800  0.9552  0.9161     7.2.1 Amide to amine reduction
# 43  0.9950  0.9888  0.9919     7.3.1 Nitrile reduction
# 44  0.9925  0.7620  0.8621     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9950  0.9056  0.9482     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9900  1.0000  0.9950     8.1.5 Alcohol to ketone oxidation
# 47  0.9888  1.0000  0.9943     8.2.1 Sulfanyl to sulfinyl
# 48  0.8900  0.9368  0.9128     9.1.6 Hydroxy to chloro
# 49  0.9825  0.7683  0.8623     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.86    0.87    0.87

# %%
utilsFunctions.labelled_cmat(cmat_fp_AP3,rtypes,figsize=(16,12),labelExtras=names_rTypes, xlabel=False, ylabel=False)

# %%
cmat_fp_MG2 = utilsFunctions.evaluateModel(result_kNN_fp_MG2, testFps_fp_MG2, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.7075  0.8956  0.7905     1.2.1 Aldehyde reductive amination
#  1  0.5450  0.6365  0.5872     1.2.4 Eschweiler-Clarke methylation
#  2  0.7887  0.9953  0.8801     1.2.5 Ketone reductive amination
#  3  0.7037  0.6866  0.6951     1.3.6 Bromo N-arylation
#  4  0.6950  0.7898  0.7394     1.3.7 Chloro N-arylation
#  5  0.7225  0.7896  0.7546     1.3.8 Fluoro N-arylation
#  6  0.4763  0.7937  0.5953     1.6.2 Bromo N-alkylation
#  7  0.4437  0.8105  0.5735     1.6.4 Chloro N-alkylation
#  8  0.3800  0.7896  0.5131     1.6.8 Iodo N-alkylation
#  9  0.9087  0.6094  0.7296     1.7.4 Hydroxy to methoxy
# 10  0.8875  0.4078  0.5588     1.7.6 Methyl esterification
# 11  0.5938  0.8467  0.6980     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.4825  0.9234  0.6338     1.7.9 Williamson ether synthesis
# 13  0.9213  0.9906  0.9547     1.8.5 Thioether synthesis
# 14  0.7488  0.8631  0.8019    10.1.1 Bromination
# 15  0.4487  0.9703  0.6137    10.1.2 Chlorination
# 16  0.8525  0.8986  0.8749    10.1.5 Wohl-Ziegler bromination
# 17  0.8788  0.9737  0.9238    10.2.1 Nitration
# 18  0.1900  0.4841  0.2729    10.4.2 Methylation
# 19  0.8013  0.6581  0.7227     2.1.1 Amide Schotten-Baumann
# 20  0.3713  0.8510  0.5170     2.1.2 Carboxylic acid + amine reaction
# 21  0.8875  0.9820  0.9324     2.1.7 N-acetylation
# 22  0.8725  0.8107  0.8405     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9912  1.0000  0.9956     2.3.1 Isocyanate + amine reaction
# 24  0.9150  0.8299  0.8704     2.6.1 Ester Schotten-Baumann
# 25  0.4875  0.7196  0.5812     2.6.3 Fischer-Speier esterification
# 26  0.9525  0.9236  0.9378     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6075  0.5400  0.5718     3.1.1 Bromo Suzuki coupling
# 28  0.4300  0.5931  0.4986     3.1.5 Bromo Suzuki-type coupling
# 29  0.9337  0.9739  0.9534     3.1.6 Chloro Suzuki-type coupling
# 30  0.9888  0.9888  0.9888     3.3.1 Sonogashira coupling
# 31  0.9237  0.9610  0.9420     3.4.1 Stille reaction
# 32  0.8900  1.0000  0.9418     5.1.1 N-Boc protection
# 33  0.9150  0.9932  0.9525     6.1.1 N-Boc deprotection
# 34  0.9100  0.9772  0.9424     6.1.3 N-Cbz deprotection
# 35  0.9900  0.9462  0.9676     6.1.5 N-Bn deprotection
# 36  0.9950  0.8652  0.9256     6.2.1 CO2H-Et deprotection
# 37  0.9962  0.7907  0.8816     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.8545  0.9210     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.8330  0.9078     6.3.1 O-Bn deprotection
# 40  0.9537  0.9658  0.9597     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9767  0.9870     7.1.1 Nitro to amino
# 42  0.6875  0.9306  0.7908     7.2.1 Amide to amine reduction
# 43  0.9975  0.9580  0.9773     7.3.1 Nitrile reduction
# 44  0.9988  0.7003  0.8233     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9962  0.9696  0.9827     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9463  0.9870  0.9662     8.1.5 Alcohol to ketone oxidation
# 47  0.8013  0.9984  0.8890     8.2.1 Sulfanyl to sulfinyl
# 48  0.8788  0.8955  0.8871     9.1.6 Hydroxy to chloro
# 49  0.9513  0.2401  0.3835     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.79    0.84    0.81

# %%
utilsFunctions.labelled_cmat(cmat_fp_MG2,rtypes,figsize=(16,12),labelExtras=names_rTypes)

# %%
cmat_fp_TT = utilsFunctions.evaluateModel(result_kNN_fp_TT, testFps_fp_TT, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.5288  0.8135  0.6409     1.2.1 Aldehyde reductive amination
#  1  0.6075  0.4714  0.5309     1.2.4 Eschweiler-Clarke methylation
#  2  0.6462  0.9923  0.7827     1.2.5 Ketone reductive amination
#  3  0.4100  0.6332  0.4977     1.3.6 Bromo N-arylation
#  4  0.6725  0.6667  0.6696     1.3.7 Chloro N-arylation
#  5  0.5525  0.7964  0.6524     1.3.8 Fluoro N-arylation
#  6  0.2037  0.4417  0.2789     1.6.2 Bromo N-alkylation
#  7  0.2625  0.6325  0.3710     1.6.4 Chloro N-alkylation
#  8  0.3225  0.5160  0.3969     1.6.8 Iodo N-alkylation
#  9  0.4963  0.5358  0.5152     1.7.4 Hydroxy to methoxy
# 10  0.9613  0.4033  0.5682     1.7.6 Methyl esterification
# 11  0.6362  0.6501  0.6431     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.2200  0.8756  0.3516     1.7.9 Williamson ether synthesis
# 13  0.5012  0.9877  0.6650     1.8.5 Thioether synthesis
# 14  0.3900  0.7446  0.5119    10.1.1 Bromination
# 15  0.3162  0.7229  0.4400    10.1.2 Chlorination
# 16  0.8263  0.9155  0.8686    10.1.5 Wohl-Ziegler bromination
# 17  0.8800  0.8789  0.8795    10.2.1 Nitration
# 18  0.0437  0.7000  0.0824    10.4.2 Methylation
# 19  0.5200  0.4546  0.4851     2.1.1 Amide Schotten-Baumann
# 20  0.3600  0.6776  0.4702     2.1.2 Carboxylic acid + amine reaction
# 21  0.8762  0.9777  0.9242     2.1.7 N-acetylation
# 22  0.8250  0.9749  0.8937     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.7625  1.0000  0.8652     2.3.1 Isocyanate + amine reaction
# 24  0.4988  0.7241  0.5907     2.6.1 Ester Schotten-Baumann
# 25  0.3175  0.5582  0.4048     2.6.3 Fischer-Speier esterification
# 26  0.8750  0.9972  0.9321     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5513  0.4830  0.5149     3.1.1 Bromo Suzuki coupling
# 28  0.2462  0.4913  0.3281     3.1.5 Bromo Suzuki-type coupling
# 29  0.8037  0.6862  0.7404     3.1.6 Chloro Suzuki-type coupling
# 30  0.8775  0.9986  0.9341     3.3.1 Sonogashira coupling
# 31  0.6713  0.9926  0.8009     3.4.1 Stille reaction
# 32  0.8912  1.0000  0.9425     5.1.1 N-Boc protection
# 33  0.8000  0.9771  0.8797     6.1.1 N-Boc deprotection
# 34  0.8725  0.9887  0.9270     6.1.3 N-Cbz deprotection
# 35  0.9575  0.9884  0.9727     6.1.5 N-Bn deprotection
# 36  0.9950  0.8984  0.9442     6.2.1 CO2H-Et deprotection
# 37  0.9550  0.7648  0.8494     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.8297  0.9064     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.8256  0.9045     6.3.1 O-Bn deprotection
# 40  0.7850  0.9501  0.8597     6.3.7 Methoxy to hydroxy
# 41  0.9688  0.9860  0.9773     7.1.1 Nitro to amino
# 42  0.5387  0.9431  0.6858     7.2.1 Amide to amine reduction
# 43  0.6925  0.8794  0.7748     7.3.1 Nitrile reduction
# 44  0.7300  0.7449  0.7374     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.7200  0.9014  0.8006     8.1.4 Alcohol to aldehyde oxidation
# 46  0.4525  0.9918  0.6215     8.1.5 Alcohol to ketone oxidation
# 47  0.6538  0.9962  0.7894     8.2.1 Sulfanyl to sulfinyl
# 48  0.7238  0.1829  0.2920     9.1.6 Hydroxy to chloro
# 49  0.8975  0.1370  0.2377     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.65    0.77    0.70

# %%
utilsFunctions.labelled_cmat(cmat_fp_TT,rtypes,figsize=(16,12),labelExtras=names_rTypes)
