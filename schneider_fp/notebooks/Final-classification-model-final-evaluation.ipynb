# %% [markdown]
# ### Test the final model (LR, AP3 + agent feature FP) by Y-scrambling and with external test set A

# %%
import cPickle,gzip
from collections import defaultdict
import random
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
import utilsFunctions
# Out:
# /usr/prog/python/2.7.5/lib/python2.7/site-packages/nose/plugins/manager.py:418: UserWarning: Module argparse was already imported from /usr/prog/python/2.7.5/lib/python2.7/argparse.pyc, but /usr/prog/python/2.7.5/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Choose some larger text size in the plots

# %%
rcParams.update({'font.size': 14})

# %%
dataDir = "../data/"
reaction_types = cPickle.load(file(dataDir+"reactionTypes_training_test_set_patent_data.pkl"))
names_rTypes = cPickle.load(file(dataDir+"names_rTypes_classes_superclasses_training_test_set_patent_data.pkl"))

# %% [markdown]
# Load the AP3 and agent feature fingerprint

# %%
infile = gzip.open(dataDir+"transformationFPs_MG2_agentFPs_test_set_patent_data.pkl.gz", 'rb')

lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_AP3,fp_agentFeature, fp_agentMG2 = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_AP3,fp_agentFeature])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %% [markdown]
# Split the FPs in training (20 %) and test data (80 %) per recation type (200, 800)

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=256
trainFps_AP3_agentFeature=[]
trainActs=[]
testFps_AP3_agentFeature=[]
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        np1 = utilsFunctions.fpToNPfloat(fps[x][3],fpsz)
        np2 = np.asarray(fps[x][4], dtype=float)
        trainFps_AP3_agentFeature += [np.concatenate([np1, np2])]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        np1 = utilsFunctions.fpToNPfloat(fps[x][3],fpsz)
        np2 = np.asarray(fps[x][4], dtype=float)
        testFps_AP3_agentFeature += [np.concatenate([np1, np2])]
    testActs += [i]*nTest
# Out:
# building fp collection

# %% [markdown]
# Test y-scrambling of our training data

# %%
import copy

lr_cls =  LogisticRegression()

trainActs_temp = copy.deepcopy(trainActs)
random.seed(42)
random.shuffle(trainActs_temp)
result_lr_cls = lr_cls.fit(trainFps_AP3_agentFeature,trainActs_temp)

# %% [markdown]
# Evaluate the y-scrambled model

# %%
cmat_fp_AP3_feature = utilsFunctions.evaluateModel(result_lr_cls, testFps_AP3_agentFeature, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.0187  0.0321  0.0237     1.2.1 Aldehyde reductive amination
#  1  0.0013  0.0022  0.0016     1.2.4 Eschweiler-Clarke methylation
#  2  0.0000  0.0000  0.0000     1.2.5 Ketone reductive amination
#  3  0.0238  0.0247  0.0242     1.3.6 Bromo N-arylation
#  4  0.0112  0.0148  0.0128     1.3.7 Chloro N-arylation
#  5  0.0000  0.0000  0.0000     1.3.8 Fluoro N-arylation
#  6  0.0037  0.0040  0.0039     1.6.2 Bromo N-alkylation
#  7  0.0175  0.0132  0.0151     1.6.4 Chloro N-alkylation
#  8  0.0063  0.0068  0.0065     1.6.8 Iodo N-alkylation
#  9  0.0037  0.0031  0.0034     1.7.4 Hydroxy to methoxy
# 10  0.0000  0.0000  0.0000     1.7.6 Methyl esterification
# 11  0.0050  0.0053  0.0051     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.0912  0.0729  0.0810     1.7.9 Williamson ether synthesis
# 13  0.0000  0.0000  0.0000     1.8.5 Thioether synthesis
# 14  0.0025  0.0031  0.0028    10.1.1 Bromination
# 15  0.0100  0.0102  0.0101    10.1.2 Chlorination
# 16  0.0125  0.0152  0.0137    10.1.5 Wohl-Ziegler bromination
# 17  0.0238  0.0241  0.0239    10.2.1 Nitration
# 18  0.0025  0.0022  0.0023    10.4.2 Methylation
# 19  0.0213  0.0206  0.0209     2.1.1 Amide Schotten-Baumann
# 20  0.0312  0.0270  0.0290     2.1.2 Carboxylic acid + amine reaction
# 21  0.0050  0.0061  0.0055     2.1.7 N-acetylation
# 22  0.0063  0.0073  0.0067     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.0512  0.0371  0.0431     2.3.1 Isocyanate + amine reaction
# 24  0.0063  0.0071  0.0066     2.6.1 Ester Schotten-Baumann
# 25  0.0025  0.0022  0.0023     2.6.3 Fischer-Speier esterification
# 26  0.0000  0.0000  0.0000     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.0625  0.0773  0.0691     3.1.1 Bromo Suzuki coupling
# 28  0.0187  0.0122  0.0148     3.1.5 Bromo Suzuki-type coupling
# 29  0.0000  0.0000  0.0000     3.1.6 Chloro Suzuki-type coupling
# 30  0.0175  0.0161  0.0168     3.3.1 Sonogashira coupling
# 31  0.0037  0.0046  0.0041     3.4.1 Stille reaction
# 32  0.0050  0.0049  0.0049     5.1.1 N-Boc protection
# 33  0.0000  0.0000  0.0000     6.1.1 N-Boc deprotection
# 34  0.0150  0.0172  0.0160     6.1.3 N-Cbz deprotection
# 35  0.1825  0.1684  0.1752     6.1.5 N-Bn deprotection
# 36  0.0425  0.0278  0.0336     6.2.1 CO2H-Et deprotection
# 37  0.0000  0.0000  0.0000     6.2.2 CO2H-Me deprotection
# 38  0.0000  0.0000  0.0000     6.2.3 CO2H-tBu deprotection
# 39  0.0037  0.0040  0.0039     6.3.1 O-Bn deprotection
# 40  0.0037  0.0051  0.0043     6.3.7 Methoxy to hydroxy
# 41  0.0000  0.0000  0.0000     7.1.1 Nitro to amino
# 42  0.0700  0.0812  0.0752     7.2.1 Amide to amine reduction
# 43  0.0063  0.0083  0.0071     7.3.1 Nitrile reduction
# 44  0.0013  0.0010  0.0011     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.0000  0.0000  0.0000     8.1.4 Alcohol to aldehyde oxidation
# 46  0.0688  0.0730  0.0708     8.1.5 Alcohol to ketone oxidation
# 47  0.0138  0.0157  0.0147     8.2.1 Sulfanyl to sulfinyl
# 48  0.0000  0.0000  0.0000     9.1.6 Hydroxy to chloro
# 49  0.0000  0.0000  0.0000     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.02    0.02    0.02

# %%
utilsFunctions.labelled_cmat(cmat_fp_AP3_feature,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %% [markdown]
# #### Build the final model and save

# %%
print 'training model'
lr_cls =  LogisticRegression()
result_lr_cls = lr_cls.fit(trainFps_AP3_agentFeature,trainActs)
# Out:
# training model

# %%
cmat_fp_AP3_feature = utilsFunctions.evaluateModel(result_lr_cls, testFps_AP3_agentFeature, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9825  0.9776  0.9800     1.2.1 Aldehyde reductive amination
#  1  0.9825  0.9481  0.9650     1.2.4 Eschweiler-Clarke methylation
#  2  0.9788  0.9703  0.9745     1.2.5 Ketone reductive amination
#  3  0.9663  0.9614  0.9638     1.3.6 Bromo N-arylation
#  4  0.9788  0.9537  0.9661     1.3.7 Chloro N-arylation
#  5  0.9862  0.9753  0.9807     1.3.8 Fluoro N-arylation
#  6  0.9525  0.9658  0.9591     1.6.2 Bromo N-alkylation
#  7  0.9087  0.9503  0.9291     1.6.4 Chloro N-alkylation
#  8  0.9250  0.9091  0.9170     1.6.8 Iodo N-alkylation
#  9  0.9750  0.9038  0.9381     1.7.4 Hydroxy to methoxy
# 10  0.9800  0.9727  0.9763     1.7.6 Methyl esterification
# 11  0.9500  0.9694  0.9596     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9450  0.9403  0.9426     1.7.9 Williamson ether synthesis
# 13  0.9688  0.9949  0.9816     1.8.5 Thioether synthesis
# 14  0.9387  0.9653  0.9518    10.1.1 Bromination
# 15  0.9237  0.9523  0.9378    10.1.2 Chlorination
# 16  0.9788  0.9514  0.9649    10.1.5 Wohl-Ziegler bromination
# 17  0.9838  0.9987  0.9912    10.2.1 Nitration
# 18  0.7163  0.8328  0.7702    10.4.2 Methylation
# 19  0.9825  0.9447  0.9632     2.1.1 Amide Schotten-Baumann
# 20  0.9700  0.9429  0.9563     2.1.2 Carboxylic acid + amine reaction
# 21  0.9463  0.9705  0.9582     2.1.7 N-acetylation
# 22  0.9938  0.9987  0.9962     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9925  1.0000  0.9962     2.3.1 Isocyanate + amine reaction
# 24  0.9750  0.9701  0.9726     2.6.1 Ester Schotten-Baumann
# 25  0.9912  0.9647  0.9778     2.6.3 Fischer-Speier esterification
# 26  0.9950  1.0000  0.9975     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.9350  0.9492  0.9421     3.1.1 Bromo Suzuki coupling
# 28  0.9600  0.9517  0.9558     3.1.5 Bromo Suzuki-type coupling
# 29  0.9812  0.9962  0.9887     3.1.6 Chloro Suzuki-type coupling
# 30  0.9938  0.9938  0.9938     3.3.1 Sonogashira coupling
# 31  0.9738  0.9924  0.9830     3.4.1 Stille reaction
# 32  0.9437  0.9934  0.9679     5.1.1 N-Boc protection
# 33  0.9975  0.9913  0.9944     6.1.1 N-Boc deprotection
# 34  0.9975  0.9950  0.9963     6.1.3 N-Cbz deprotection
# 35  0.9925  0.9975  0.9950     6.1.5 N-Bn deprotection
# 36  0.9950  0.9648  0.9797     6.2.1 CO2H-Et deprotection
# 37  0.9888  0.9729  0.9808     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9901  0.9944     6.2.3 CO2H-tBu deprotection
# 39  0.9988  0.9950  0.9969     6.3.1 O-Bn deprotection
# 40  0.9962  0.9876  0.9919     6.3.7 Methoxy to hydroxy
# 41  0.9900  0.9962  0.9931     7.1.1 Nitro to amino
# 42  0.9938  0.9815  0.9876     7.2.1 Amide to amine reduction
# 43  0.9950  0.9962  0.9956     7.3.1 Nitrile reduction
# 44  0.9975  0.9925  0.9950     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9988  0.9852  0.9919     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9938  0.9839  0.9888     8.1.5 Alcohol to ketone oxidation
# 47  0.9925  0.9962  0.9944     8.2.1 Sulfanyl to sulfinyl
# 48  0.9663  0.9614  0.9638     9.1.6 Hydroxy to chloro
# 49  0.9788  0.9691  0.9739     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.97    0.97    0.97

# %% [markdown]
# Store the model as scikit-learn model

# %%
from sklearn.externals import joblib

# %%
joblib.dump(result_lr_cls, dataDir+'LR_transformationFP256bit.AP3.agent_featureFP.pkl')
# Out:
# ['../data/LR_transformationFP256bit.AP3.agent_featureFP.pkl',
#  '../data/LR_transformationFP256bit.AP3.agent_featureFP.pkl_01.npy',
#  '../data/LR_transformationFP256bit.AP3.agent_featureFP.pkl_02.npy',
#  '../data/LR_transformationFP256bit.AP3.agent_featureFP.pkl_03.npy',
#  '../data/LR_transformationFP256bit.AP3.agent_featureFP.pkl_04.npy',
#  '../data/LR_transformationFP256bit.AP3.agent_featureFP.pkl_05.npy']

# %% [markdown]
# #### Load the new model and test on external test set A

# %%
clf = joblib.load(dataDir+'LR_transformationFP256bit.AP3.agent_featureFP.pkl')

# %% [markdown]
# Test the final model (LR, AP3 256 bit + agent featureFP) with external test set A (another 50000 reactions randomly selected form the patent data)

# %% [markdown]
# Load the FPs

# %%
infile = gzip.open(dataDir+"transformationFPs_agentFPs_external_test_set_A.pkl.gz", 'rb')
lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_AP3,fp_agentFeature = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_AP3,fp_agentFeature])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %% [markdown]
# Combine the FPs of the external test set

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

fpsz=256

testFps_AP3_agentFeature=[]
testActs=[]
print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    nTest=len(actIds)
    for x in actIds:
        np1 = utilsFunctions.fpToNPfloat(fps[x][3],fpsz)
        np2 = np.asarray(fps[x][4], dtype=float)
        testFps_AP3_agentFeature += [np.concatenate([np1, np2])]
    testActs += [i]*nTest
# Out:
# building fp collection

# %% [markdown]
# Evaluate the model performance

# %%
cmat_fp_AP3_feature = utilsFunctions.evaluateModel(clf, testFps_AP3_agentFeature, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9850  0.9821  0.9835     1.2.1 Aldehyde reductive amination
#  1  0.9860  0.9573  0.9714     1.2.4 Eschweiler-Clarke methylation
#  2  0.9820  0.9761  0.9791     1.2.5 Ketone reductive amination
#  3  0.9720  0.9681  0.9701     1.3.6 Bromo N-arylation
#  4  0.9820  0.9609  0.9713     1.3.7 Chloro N-arylation
#  5  0.9890  0.9792  0.9841     1.3.8 Fluoro N-arylation
#  6  0.9610  0.9717  0.9663     1.6.2 Bromo N-alkylation
#  7  0.9240  0.9565  0.9400     1.6.4 Chloro N-alkylation
#  8  0.9350  0.9194  0.9271     1.6.8 Iodo N-alkylation
#  9  0.9770  0.9131  0.9440     1.7.4 Hydroxy to methoxy
# 10  0.9800  0.9761  0.9780     1.7.6 Methyl esterification
# 11  0.9530  0.9754  0.9641     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9540  0.9502  0.9521     1.7.9 Williamson ether synthesis
# 13  0.9750  0.9949  0.9848     1.8.5 Thioether synthesis
# 14  0.9490  0.9713  0.9600    10.1.1 Bromination
# 15  0.9390  0.9611  0.9499    10.1.2 Chlorination
# 16  0.9820  0.9590  0.9704    10.1.5 Wohl-Ziegler bromination
# 17  0.9860  0.9990  0.9925    10.2.1 Nitration
# 18  0.7410  0.8586  0.7955    10.4.2 Methylation
# 19  0.9850  0.9554  0.9700     2.1.1 Amide Schotten-Baumann
# 20  0.9730  0.9539  0.9634     2.1.2 Carboxylic acid + amine reaction
# 21  0.9550  0.9735  0.9642     2.1.7 N-acetylation
# 22  0.9950  0.9990  0.9970     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9940  1.0000  0.9970     2.3.1 Isocyanate + amine reaction
# 24  0.9780  0.9751  0.9765     2.6.1 Ester Schotten-Baumann
# 25  0.9920  0.9669  0.9793     2.6.3 Fischer-Speier esterification
# 26  0.9960  1.0000  0.9980     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.9430  0.9564  0.9496     3.1.1 Bromo Suzuki coupling
# 28  0.9660  0.9564  0.9612     3.1.5 Bromo Suzuki-type coupling
# 29  0.9840  0.9970  0.9904     3.1.6 Chloro Suzuki-type coupling
# 30  0.9950  0.9950  0.9950     3.3.1 Sonogashira coupling
# 31  0.9790  0.9939  0.9864     3.4.1 Stille reaction
# 32  0.9550  0.9938  0.9740     5.1.1 N-Boc protection
# 33  0.9970  0.9911  0.9940     6.1.1 N-Boc deprotection
# 34  0.9980  0.9960  0.9970     6.1.3 N-Cbz deprotection
# 35  0.9940  0.9970  0.9955     6.1.5 N-Bn deprotection
# 36  0.9960  0.9689  0.9822     6.2.1 CO2H-Et deprotection
# 37  0.9910  0.9716  0.9812     6.2.2 CO2H-Me deprotection
# 38  0.9990  0.9911  0.9950     6.2.3 CO2H-tBu deprotection
# 39  0.9990  0.9960  0.9975     6.3.1 O-Bn deprotection
# 40  0.9970  0.9891  0.9930     6.3.7 Methoxy to hydroxy
# 41  0.9920  0.9960  0.9940     7.1.1 Nitro to amino
# 42  0.9950  0.9832  0.9891     7.2.1 Amide to amine reduction
# 43  0.9960  0.9970  0.9965     7.3.1 Nitrile reduction
# 44  0.9980  0.9930  0.9955     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9990  0.9881  0.9935     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9950  0.9861  0.9905     8.1.5 Alcohol to ketone oxidation
# 47  0.9940  0.9970  0.9955     8.2.1 Sulfanyl to sulfinyl
# 48  0.9710  0.9691  0.9700     9.1.6 Hydroxy to chloro
# 49  0.9830  0.9723  0.9776     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.97    0.97    0.97

# %%
utilsFunctions.labelled_cmat(cmat_fp_AP3_feature,rtypes,figsize=(16,12), labelExtras=names_rTypes)
