# %% [markdown]
# ### Learning reaction types using a Random Forest classifier and more local difference fingerprints (AP3, MG2, TT)

# %%
import cPickle,gzip
from collections import defaultdict
import random
from sklearn.ensemble import RandomForestClassifier
import utilsFunctions
# Out:
# /usr/prog/python/2.7.5/lib/python2.7/site-packages/nose/plugins/manager.py:418: UserWarning: Module argparse was already imported from /usr/prog/python/2.7.5/lib/python2.7/argparse.pyc, but /usr/prog/python/2.7.5/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Choose some larger text size in the plots

# %%
rcParams.update({'font.size': 14})

# %%
dataDir = "../data/"
reaction_types = cPickle.load(file(dataDir+"reactionTypes_training_test_set_patent_data.pkl"))
names_rTypes = cPickle.load(file(dataDir+"names_rTypes_classes_superclasses_training_test_set_patent_data.pkl"))

# %% [markdown]
# Load the different FPs (AP3, MG2, TT)

# %%
infile = gzip.open(dataDir+"transformationFPs_test_set_patent_data.pkl.gz", 'rb')

lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_AP3,fp_MG2,fp_TT = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_AP3,fp_MG2,fp_TT])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %% [markdown]
# Split the FPs in training (20 %) and test data (80 %) per recation type (200, 800)

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=2048 # the FPs bit size for converting the FPs to a numpy array
#fpsz=4096
trainFps_fp_AP3=[]
trainFps_fp_MG2=[]
trainFps_fp_TT=[]
trainActs=[]
testFps_fp_AP3=[]
testFps_fp_MG2=[]
testFps_fp_TT=[]
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        trainFps_fp_AP3 += [utilsFunctions.fpToNP(fps[x][3],fpsz)]
        trainFps_fp_MG2 += [utilsFunctions.fpToNP(fps[x][4],fpsz)]
        trainFps_fp_TT += [utilsFunctions.fpToNP(fps[x][5],fpsz)]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        testFps_fp_AP3 += [utilsFunctions.fpToNP(fps[x][3],fpsz)]
        testFps_fp_MG2 += [utilsFunctions.fpToNP(fps[x][4],fpsz)]
        testFps_fp_TT += [utilsFunctions.fpToNP(fps[x][5],fpsz)]
    testActs += [i]*nTest
# Out:
# building fp collection

# %% [markdown]
# Build the RF classifiers with max tree depth of 25

# %%
print 'training models'
rf_cls_AP3 = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_fp_AP3 = rf_cls_AP3.fit(trainFps_fp_AP3,trainActs)
rf_cls_MG2 = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_fp_MG2 = rf_cls_MG2.fit(trainFps_fp_MG2,trainActs)
rf_cls_TT = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_fp_TT = rf_cls_TT.fit(trainFps_fp_TT,trainActs)
# Out:
# training models

# %% [markdown]
# Evaluate the RF classifier using our test data

# %%
cmat_fp_AP3 = utilsFunctions.evaluateModel(result_rf_fp_AP3, testFps_fp_AP3, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9862  0.9838  0.9850     1.2.1 Aldehyde reductive amination
#  1  0.9938  0.8983  0.9436     1.2.4 Eschweiler-Clarke methylation
#  2  0.9875  0.9814  0.9844     1.2.5 Ketone reductive amination
#  3  0.9788  0.9468  0.9625     1.3.6 Bromo N-arylation
#  4  0.9812  0.9401  0.9602     1.3.7 Chloro N-arylation
#  5  0.9900  0.9730  0.9814     1.3.8 Fluoro N-arylation
#  6  0.9375  0.9753  0.9560     1.6.2 Bromo N-alkylation
#  7  0.9100  0.9566  0.9327     1.6.4 Chloro N-alkylation
#  8  0.9125  0.8528  0.8816     1.6.8 Iodo N-alkylation
#  9  0.9850  0.9370  0.9604     1.7.4 Hydroxy to methoxy
# 10  0.8612  0.7215  0.7852     1.7.6 Methyl esterification
# 11  0.9500  0.9632  0.9566     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9237  0.9788  0.9505     1.7.9 Williamson ether synthesis
# 13  0.9925  0.9742  0.9833     1.8.5 Thioether synthesis
# 14  0.9313  0.9625  0.9466    10.1.1 Bromination
# 15  0.9563  0.9733  0.9647    10.1.2 Chlorination
# 16  0.9700  0.9510  0.9604    10.1.5 Wohl-Ziegler bromination
# 17  0.9900  0.9950  0.9925    10.2.1 Nitration
# 18  0.6937  0.9204  0.7912    10.4.2 Methylation
# 19  0.9812  0.9446  0.9626     2.1.1 Amide Schotten-Baumann
# 20  0.9738  0.9558  0.9647     2.1.2 Carboxylic acid + amine reaction
# 21  0.9437  0.9742  0.9587     2.1.7 N-acetylation
# 22  0.9975  0.9925  0.9950     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9938  0.9900  0.9919     2.3.1 Isocyanate + amine reaction
# 24  0.9825  0.9850  0.9837     2.6.1 Ester Schotten-Baumann
# 25  0.6587  0.8070  0.7254     2.6.3 Fischer-Speier esterification
# 26  0.9975  0.9950  0.9963     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6312  0.5719  0.6001     3.1.1 Bromo Suzuki coupling
# 28  0.5075  0.6078  0.5531     3.1.5 Bromo Suzuki-type coupling
# 29  0.9812  0.9987  0.9899     3.1.6 Chloro Suzuki-type coupling
# 30  0.9975  0.9779  0.9876     3.3.1 Sonogashira coupling
# 31  0.9575  0.9684  0.9629     3.4.1 Stille reaction
# 32  0.9625  1.0000  0.9809     5.1.1 N-Boc protection
# 33  0.9988  0.9889  0.9938     6.1.1 N-Boc deprotection
# 34  1.0000  0.9950  0.9975     6.1.3 N-Cbz deprotection
# 35  0.9938  0.9695  0.9815     6.1.5 N-Bn deprotection
# 36  0.9938  0.9900  0.9919     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9827  0.9888     6.2.2 CO2H-Me deprotection
# 38  0.9988  1.0000  0.9994     6.2.3 CO2H-tBu deprotection
# 39  0.9988  0.9840  0.9913     6.3.1 O-Bn deprotection
# 40  0.9975  0.9815  0.9895     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9852  0.9913     7.1.1 Nitro to amino
# 42  1.0000  0.9756  0.9877     7.2.1 Amide to amine reduction
# 43  0.9988  0.9975  0.9981     7.3.1 Nitrile reduction
# 44  0.9988  0.9925  0.9956     7.9.2 Carboxylic acid to alcohol reduction
# 45  1.0000  0.9901  0.9950     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9988  0.9756  0.9870     8.1.5 Alcohol to ketone oxidation
# 47  0.9925  0.9987  0.9956     8.2.1 Sulfanyl to sulfinyl
# 48  0.9850  0.9825  0.9838     9.1.6 Hydroxy to chloro
# 49  0.9825  0.9924  0.9874     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.95    0.95    0.95

# %% [markdown]
# Draw the confusion matix

# %%
utilsFunctions.labelled_cmat(cmat_fp_AP3,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %%
cmat_fp_MG2 = utilsFunctions.evaluateModel(result_rf_fp_MG2, testFps_fp_MG2, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9862  0.9681  0.9771     1.2.1 Aldehyde reductive amination
#  1  0.9463  0.8916  0.9181     1.2.4 Eschweiler-Clarke methylation
#  2  0.9812  0.9788  0.9800     1.2.5 Ketone reductive amination
#  3  0.9725  0.8851  0.9267     1.3.6 Bromo N-arylation
#  4  0.9825  0.9313  0.9562     1.3.7 Chloro N-arylation
#  5  0.9900  0.9384  0.9635     1.3.8 Fluoro N-arylation
#  6  0.9175  0.9879  0.9514     1.6.2 Bromo N-alkylation
#  7  0.8712  0.9601  0.9135     1.6.4 Chloro N-alkylation
#  8  0.9062  0.8610  0.8831     1.6.8 Iodo N-alkylation
#  9  0.9675  0.9042  0.9348     1.7.4 Hydroxy to methoxy
# 10  0.7762  0.7921  0.7841     1.7.6 Methyl esterification
# 11  0.9300  0.9789  0.9538     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9187  0.9658  0.9417     1.7.9 Williamson ether synthesis
# 13  0.9938  0.9487  0.9707     1.8.5 Thioether synthesis
# 14  0.9287  0.9526  0.9405    10.1.1 Bromination
# 15  0.9337  0.9676  0.9504    10.1.2 Chlorination
# 16  0.9788  0.9479  0.9631    10.1.5 Wohl-Ziegler bromination
# 17  0.9900  0.9888  0.9894    10.2.1 Nitration
# 18  0.5613  0.8685  0.6819    10.4.2 Methylation
# 19  0.9800  0.9138  0.9457     2.1.1 Amide Schotten-Baumann
# 20  0.9738  0.9523  0.9629     2.1.2 Carboxylic acid + amine reaction
# 21  0.9363  0.9753  0.9554     2.1.7 N-acetylation
# 22  0.9875  0.9937  0.9906     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9938  0.9975  0.9956     2.3.1 Isocyanate + amine reaction
# 24  0.9688  0.9823  0.9755     2.6.1 Ester Schotten-Baumann
# 25  0.8175  0.7605  0.7880     2.6.3 Fischer-Speier esterification
# 26  0.9950  0.9987  0.9969     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5900  0.5827  0.5863     3.1.1 Bromo Suzuki coupling
# 28  0.5537  0.6077  0.5795     3.1.5 Bromo Suzuki-type coupling
# 29  0.9812  0.9937  0.9874     3.1.6 Chloro Suzuki-type coupling
# 30  0.9975  0.9791  0.9882     3.3.1 Sonogashira coupling
# 31  0.9563  0.9720  0.9641     3.4.1 Stille reaction
# 32  0.9513  1.0000  0.9750     5.1.1 N-Boc protection
# 33  0.9988  0.9925  0.9956     6.1.1 N-Boc deprotection
# 34  0.9988  0.9963  0.9975     6.1.3 N-Cbz deprotection
# 35  0.9962  0.9731  0.9846     6.1.5 N-Bn deprotection
# 36  0.9975  0.9626  0.9797     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9719  0.9833     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9988  0.9988     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9950  0.9975     6.3.1 O-Bn deprotection
# 40  0.9888  0.9694  0.9790     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9840  0.9907     7.1.1 Nitro to amino
# 42  0.9962  0.9579  0.9767     7.2.1 Amide to amine reduction
# 43  0.9988  0.9901  0.9944     7.3.1 Nitrile reduction
# 44  0.9975  0.9864  0.9919     7.9.2 Carboxylic acid to alcohol reduction
# 45  1.0000  0.9864  0.9932     8.1.4 Alcohol to aldehyde oxidation
# 46  1.0000  0.9581  0.9786     8.1.5 Alcohol to ketone oxidation
# 47  0.9838  0.9899  0.9868     8.2.1 Sulfanyl to sulfinyl
# 48  0.9675  0.9847  0.9760     9.1.6 Hydroxy to chloro
# 49  0.9888  0.9802  0.9844     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.94    0.94    0.94

# %%
utilsFunctions.labelled_cmat(cmat_fp_MG2,rtypes,figsize=(16,12),labelExtras=names_rTypes)

# %%
cmat_fp_TT = utilsFunctions.evaluateModel(result_rf_fp_TT, testFps_fp_TT, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.7700  0.9019  0.8307     1.2.1 Aldehyde reductive amination
#  1  0.9100  0.7102  0.7978     1.2.4 Eschweiler-Clarke methylation
#  2  0.9025  0.8555  0.8783     1.2.5 Ketone reductive amination
#  3  0.9100  0.7728  0.8358     1.3.6 Bromo N-arylation
#  4  0.9200  0.8402  0.8783     1.3.7 Chloro N-arylation
#  5  0.9788  0.9223  0.9497     1.3.8 Fluoro N-arylation
#  6  0.5212  0.6132  0.5635     1.6.2 Bromo N-alkylation
#  7  0.4988  0.6552  0.5664     1.6.4 Chloro N-alkylation
#  8  0.5900  0.5599  0.5746     1.6.8 Iodo N-alkylation
#  9  0.6713  0.8935  0.7666     1.7.4 Hydroxy to methoxy
# 10  0.9875  0.6220  0.7633     1.7.6 Methyl esterification
# 11  0.7788  0.6728  0.7219     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.6050  0.8752  0.7154     1.7.9 Williamson ether synthesis
# 13  0.8050  0.9758  0.8822     1.8.5 Thioether synthesis
# 14  0.7837  0.9167  0.8450    10.1.1 Bromination
# 15  0.7375  0.8514  0.7904    10.1.2 Chlorination
# 16  0.9137  0.8969  0.9053    10.1.5 Wohl-Ziegler bromination
# 17  0.9575  0.9575  0.9575    10.2.1 Nitration
# 18  0.3237  0.8019  0.4613    10.4.2 Methylation
# 19  0.6200  0.7538  0.6804     2.1.1 Amide Schotten-Baumann
# 20  0.7562  0.7442  0.7502     2.1.2 Carboxylic acid + amine reaction
# 21  0.9025  0.9810  0.9401     2.1.7 N-acetylation
# 22  0.9587  0.8981  0.9274     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9812  0.9620  0.9715     2.3.1 Isocyanate + amine reaction
# 24  0.8962  0.7563  0.8204     2.6.1 Ester Schotten-Baumann
# 25  0.3588  0.7928  0.4940     2.6.3 Fischer-Speier esterification
# 26  0.9250  0.9724  0.9481     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5800  0.5370  0.5577     3.1.1 Bromo Suzuki coupling
# 28  0.4587  0.5681  0.5076     3.1.5 Bromo Suzuki-type coupling
# 29  0.9600  0.9343  0.9470     3.1.6 Chloro Suzuki-type coupling
# 30  0.9850  0.9765  0.9807     3.3.1 Sonogashira coupling
# 31  0.8125  0.9716  0.8850     3.4.1 Stille reaction
# 32  0.9587  0.9884  0.9734     5.1.1 N-Boc protection
# 33  0.9988  0.9889  0.9938     6.1.1 N-Boc deprotection
# 34  0.9988  0.9988  0.9988     6.1.3 N-Cbz deprotection
# 35  0.9962  0.9522  0.9737     6.1.5 N-Bn deprotection
# 36  0.9975  0.9225  0.9586     6.2.1 CO2H-Et deprotection
# 37  0.9912  0.9659  0.9784     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9546  0.9762     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9840  0.9919     6.3.1 O-Bn deprotection
# 40  0.9513  0.9524  0.9518     6.3.7 Methoxy to hydroxy
# 41  0.9725  0.9534  0.9629     7.1.1 Nitro to amino
# 42  0.9375  0.8876  0.9119     7.2.1 Amide to amine reduction
# 43  0.6075  0.9328  0.7358     7.3.1 Nitrile reduction
# 44  0.7475  0.9403  0.8329     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.8413  0.5945  0.6967     8.1.4 Alcohol to aldehyde oxidation
# 46  0.7987  0.9181  0.8543     8.1.5 Alcohol to ketone oxidation
# 47  0.9350  0.9627  0.9486     8.2.1 Sulfanyl to sulfinyl
# 48  0.8912  0.3275  0.4790     9.1.6 Hydroxy to chloro
# 49  0.6412  0.8382  0.7266     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.82    0.84    0.83

# %%
utilsFunctions.labelled_cmat(cmat_fp_TT,rtypes,figsize=(16,12),labelExtras=names_rTypes)
