# %% [markdown]
# ### Learning reaction types using a Random Forest classifier and different reaction fingerprints

# %% [markdown]
# Goal: Include special fingerprints for agents (feature FP, Morgan2, dictionary-based FP), concatenate them with the 2048 bit reaction FP

# %%
import cPickle,gzip
from collections import defaultdict
import random
from sklearn.ensemble import RandomForestClassifier
import utilsFunctions
# Out:
# /usr/prog/python/2.7.5/lib/python2.7/site-packages/nose/plugins/manager.py:418: UserWarning: Module argparse was already imported from /usr/prog/python/2.7.5/lib/python2.7/argparse.pyc, but /usr/prog/python/2.7.5/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Choose some larger text size in the plots

# %%
rcParams.update({'font.size': 14})

# %%
dataDir = "../data/"
reaction_types = cPickle.load(file(dataDir+"reactionTypes_training_test_set_patent_data.pkl"))
names_rTypes = cPickle.load(file(dataDir+"names_rTypes_classes_superclasses_training_test_set_patent_data.pkl"))

# %% [markdown]
# #### First: test the agent feature FPs

# %% [markdown]
# Load the FPs (reaction FP and agent feature FP)

# %%
infile = gzip.open(dataDir+"reaction_FPs_agentFeatureFPs_training_test_set_patent_data.pkl.gz", 'rb')

lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_woA,fp_featureAgent = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_woA,fp_featureAgent])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %% [markdown]
# Build the combination of reaction FP and agent feature FPs. Split the FPs in training (20 %) and test data (80 %) per recation type (200, 800)

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=2048 # the FPs bit size for converting the FPs to a numpy array
#fpsz=4096
trainFps_rFP_agentFeature=[]
trainActs=[]
testFps_rFP_agentFeature=[]
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        np1 = utilsFunctions.hashedFPToNPfloat(fps[x][3],fpsz)
        np2 = np.asarray(fps[x][4], dtype=float)
        trainFps_rFP_agentFeature += [np.concatenate([np1, np2])]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        np1 = utilsFunctions.hashedFPToNPfloat(fps[x][3],fpsz)
        np2 = np.asarray(fps[x][4], dtype=float)
        testFps_rFP_agentFeature += [np.concatenate([np1, np2])]
    testActs += [i]*nTest
# Out:
# building fp collection

# %% [markdown]
# Build the RF classifier with max tree depth of 25

# %%
print 'training model'
rf_cls = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_rFP_agentFeature = rf_cls.fit(trainFps_rFP_agentFeature,trainActs)
# Out:
# training model

# %% [markdown]
# Evaluate the RF classifier using our test data

# %%
cmat_rFP_agentFeature = utilsFunctions.evaluateModel(result_rf_rFP_agentFeature, testFps_rFP_agentFeature, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9800  0.9849  0.9825     1.2.1 Aldehyde reductive amination
#  1  0.9912  0.8278  0.9022     1.2.4 Eschweiler-Clarke methylation
#  2  0.9862  0.9753  0.9807     1.2.5 Ketone reductive amination
#  3  0.9663  0.9392  0.9526     1.3.6 Bromo N-arylation
#  4  0.9775  0.9365  0.9566     1.3.7 Chloro N-arylation
#  5  0.9900  0.9395  0.9641     1.3.8 Fluoro N-arylation
#  6  0.9062  0.9283  0.9171     1.6.2 Bromo N-alkylation
#  7  0.8762  0.9629  0.9175     1.6.4 Chloro N-alkylation
#  8  0.7875  0.8537  0.8192     1.6.8 Iodo N-alkylation
#  9  0.9850  0.9184  0.9505     1.7.4 Hydroxy to methoxy
# 10  0.9725  0.9762  0.9743     1.7.6 Methyl esterification
# 11  0.9263  0.9611  0.9433     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9213  0.9647  0.9425     1.7.9 Williamson ether synthesis
# 13  0.9875  0.9826  0.9850     1.8.5 Thioether synthesis
# 14  0.9375  0.9615  0.9494    10.1.1 Bromination
# 15  0.9613  0.9710  0.9661    10.1.2 Chlorination
# 16  0.9850  0.9586  0.9716    10.1.5 Wohl-Ziegler bromination
# 17  0.9900  0.9937  0.9919    10.2.1 Nitration
# 18  0.7087  0.8846  0.7870    10.4.2 Methylation
# 19  0.9788  0.9201  0.9485     2.1.1 Amide Schotten-Baumann
# 20  0.9650  0.9507  0.9578     2.1.2 Carboxylic acid + amine reaction
# 21  0.9313  0.9816  0.9557     2.1.7 N-acetylation
# 22  0.9950  0.9938  0.9944     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9938  0.9913  0.9925     2.3.1 Isocyanate + amine reaction
# 24  0.9812  0.9837  0.9825     2.6.1 Ester Schotten-Baumann
# 25  0.9750  0.9618  0.9683     2.6.3 Fischer-Speier esterification
# 26  0.9962  0.9938  0.9950     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.9200  0.9787  0.9485     3.1.1 Bromo Suzuki coupling
# 28  0.9587  0.9423  0.9504     3.1.5 Bromo Suzuki-type coupling
# 29  0.9788  0.9987  0.9886     3.1.6 Chloro Suzuki-type coupling
# 30  0.9975  0.9767  0.9870     3.3.1 Sonogashira coupling
# 31  0.9437  0.9818  0.9624     3.4.1 Stille reaction
# 32  0.9600  0.9961  0.9777     5.1.1 N-Boc protection
# 33  0.9975  0.9901  0.9938     6.1.1 N-Boc deprotection
# 34  1.0000  0.9963  0.9981     6.1.3 N-Cbz deprotection
# 35  0.9938  0.9601  0.9767     6.1.5 N-Bn deprotection
# 36  0.9975  0.9803  0.9888     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9864  0.9907     6.2.2 CO2H-Me deprotection
# 38  0.9988  1.0000  0.9994     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9840  0.9919     6.3.1 O-Bn deprotection
# 40  0.9962  0.9852  0.9907     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9840  0.9907     7.1.1 Nitro to amino
# 42  1.0000  0.9828  0.9913     7.2.1 Amide to amine reduction
# 43  0.9988  0.9975  0.9981     7.3.1 Nitrile reduction
# 44  0.9975  0.9901  0.9938     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9950  0.9864  0.9907     8.1.4 Alcohol to aldehyde oxidation
# 46  1.0000  0.9852  0.9926     8.1.5 Alcohol to ketone oxidation
# 47  0.9925  0.9937  0.9931     8.2.1 Sulfanyl to sulfinyl
# 48  0.9725  0.9848  0.9786     9.1.6 Hydroxy to chloro
# 49  0.9825  0.9813  0.9819     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.97    0.97    0.97

# %% [markdown]
# Draw the confusion matrix

# %%
utilsFunctions.labelled_cmat(cmat_rFP_agentFeature,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %% [markdown]
# #### Second: test the agent Morgan2 FPs

# %% [markdown]
# Load the FPs (reaction FP and agent Morgan2 FP)

# %%
infile = gzip.open(dataDir+"reaction_FPs_agentMG2FPs_training_test_set_patent_data.pkl.gz", 'rb')

lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_woA,fp_MG2_agents = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_woA,fp_MG2_agents])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %% [markdown]
# Build the combination of reaction FP and agent Morgan2 FP. Split the FPs in training (20 %) and test data (80 %) per recation type (200, 800)

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=2048 # the FPs bit size for converting the FPs to a numpy array
#fpsz=4096

trainFps_rFP_agentMG2=[]
trainActs=[]
testFps_rFP_agentMG2=[]
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        np1 = utilsFunctions.hashedFPToNP(fps[x][3],fpsz)
        np2 = utilsFunctions.fpToNP(fps[x][4],fpsz)
        trainFps_rFP_agentMG2 += [np.concatenate([np1, np2])]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        np1 = utilsFunctions.hashedFPToNP(fps[x][3],fpsz)
        np2 = utilsFunctions.fpToNP(fps[x][4],fpsz)
        testFps_rFP_agentMG2 += [np.concatenate([np1, np2])]
    testActs += [i]*nTest
# Out:
# building fp collection

# %%
print 'training model'
rf_cls = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_rFP_agentMG2 = rf_cls.fit(trainFps_rFP_agentMG2,trainActs)
# Out:
# training model

# %%
cmat_rFP_agentMG2 = utilsFunctions.evaluateModel(result_rf_rFP_agentMG2, testFps_rFP_agentMG2, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9800  0.9788  0.9794     1.2.1 Aldehyde reductive amination
#  1  0.9925  0.8135  0.8941     1.2.4 Eschweiler-Clarke methylation
#  2  0.9850  0.9716  0.9783     1.2.5 Ketone reductive amination
#  3  0.9738  0.9318  0.9523     1.3.6 Bromo N-arylation
#  4  0.9800  0.9389  0.9590     1.3.7 Chloro N-arylation
#  5  0.9900  0.9406  0.9647     1.3.8 Fluoro N-arylation
#  6  0.9000  0.9243  0.9120     1.6.2 Bromo N-alkylation
#  7  0.8425  0.9427  0.8898     1.6.4 Chloro N-alkylation
#  8  0.7288  0.8486  0.7841     1.6.8 Iodo N-alkylation
#  9  0.9738  0.9318  0.9523     1.7.4 Hydroxy to methoxy
# 10  0.9862  0.9753  0.9807     1.7.6 Methyl esterification
# 11  0.8625  0.9857  0.9200     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9563  0.9318  0.9439     1.7.9 Williamson ether synthesis
# 13  0.9900  0.9730  0.9814     1.8.5 Thioether synthesis
# 14  0.9487  0.9922  0.9700    10.1.1 Bromination
# 15  0.9600  0.9709  0.9654    10.1.2 Chlorination
# 16  0.9988  0.9792  0.9889    10.1.5 Wohl-Ziegler bromination
# 17  0.9812  0.9924  0.9868    10.2.1 Nitration
# 18  0.7288  0.8942  0.8030    10.4.2 Methylation
# 19  0.9800  0.9180  0.9480     2.1.1 Amide Schotten-Baumann
# 20  0.9625  0.9483  0.9553     2.1.2 Carboxylic acid + amine reaction
# 21  0.9225  0.9827  0.9516     2.1.7 N-acetylation
# 22  0.9962  0.9901  0.9931     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9938  0.9888  0.9913     2.3.1 Isocyanate + amine reaction
# 24  0.9825  0.9668  0.9746     2.6.1 Ester Schotten-Baumann
# 25  0.9950  0.9637  0.9791     2.6.3 Fischer-Speier esterification
# 26  0.9962  0.9975  0.9969     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.9200  0.9906  0.9540     3.1.1 Bromo Suzuki coupling
# 28  0.9712  0.9395  0.9551     3.1.5 Bromo Suzuki-type coupling
# 29  0.9750  0.9987  0.9867     3.1.6 Chloro Suzuki-type coupling
# 30  0.9975  0.9840  0.9907     3.3.1 Sonogashira coupling
# 31  0.9575  0.9871  0.9721     3.4.1 Stille reaction
# 32  0.9600  0.9987  0.9790     5.1.1 N-Boc protection
# 33  0.9975  0.9901  0.9938     6.1.1 N-Boc deprotection
# 34  1.0000  0.9950  0.9975     6.1.3 N-Cbz deprotection
# 35  0.9938  0.9625  0.9779     6.1.5 N-Bn deprotection
# 36  0.9962  0.9755  0.9858     6.2.1 CO2H-Et deprotection
# 37  0.9962  0.9779  0.9870     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9988  0.9988     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9828  0.9913     6.3.1 O-Bn deprotection
# 40  0.9912  0.9802  0.9857     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9803  0.9888     7.1.1 Nitro to amino
# 42  1.0000  0.9780  0.9889     7.2.1 Amide to amine reduction
# 43  0.9988  0.9963  0.9975     7.3.1 Nitrile reduction
# 44  0.9988  0.9828  0.9907     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9938  0.9864  0.9900     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9988  0.9768  0.9876     8.1.5 Alcohol to ketone oxidation
# 47  0.9925  0.9950  0.9937     8.2.1 Sulfanyl to sulfinyl
# 48  0.9650  0.9822  0.9735     9.1.6 Hydroxy to chloro
# 49  0.9812  0.9739  0.9776     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.97    0.97    0.97

# %%
utilsFunctions.labelled_cmat(cmat_rFP_agentMG2,rtypes,figsize=(16,12),labelExtras=names_rTypes)

# %% [markdown]
# #### Third: test the agent dictionary-based FP

# %% [markdown]
# Load the FPs (reaction FP and agent dictionary-based FP)

# %%
infile = gzip.open(dataDir+"reaction_FPs_agentDictBasedFPs_training_test_set_patent_data.pkl.gz", 'rb')

lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_woA,fp_dictinarybased_agents = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_woA,fp_dictinarybased_agents])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=2048 # the FPs bit size for converting the FPs to a numpy array
#fpsz=4096

trainFps_rFP_agentDictBased=[]
trainActs=[]
testFps_rFP_agentDictBased=[]
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        np1 = utilsFunctions.hashedFPToNP(fps[x][3],fpsz)
        np2 = utilsFunctions.fpDictToNP(fps[x][4])
        trainFps_rFP_agentDictBased += [np.concatenate([np1, np2])]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        np1 = utilsFunctions.hashedFPToNP(fps[x][3],fpsz)
        np2 = utilsFunctions.fpDictToNP(fps[x][4])
        testFps_rFP_agentDictBased += [np.concatenate([np1, np2])]
    testActs += [i]*nTest
# Out:
# building fp collection

# %%
print 'training model'
rf_cls = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_rFP_agentDictBased = rf_cls.fit(trainFps_rFP_agentDictBased,trainActs)
# Out:
# training model

# %%
cmat_rFP_agentDictBased = utilsFunctions.evaluateModel(result_rf_rFP_agentDictBased, testFps_rFP_agentDictBased, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9675  0.9847  0.9760     1.2.1 Aldehyde reductive amination
#  1  0.9925  0.8340  0.9064     1.2.4 Eschweiler-Clarke methylation
#  2  0.9850  0.9777  0.9813     1.2.5 Ketone reductive amination
#  3  0.9663  0.9543  0.9602     1.3.6 Bromo N-arylation
#  4  0.9788  0.9212  0.9491     1.3.7 Chloro N-arylation
#  5  0.9900  0.9274  0.9577     1.3.8 Fluoro N-arylation
#  6  0.9213  0.8988  0.9099     1.6.2 Bromo N-alkylation
#  7  0.8750  0.9642  0.9174     1.6.4 Chloro N-alkylation
#  8  0.7425  0.8193  0.7790     1.6.8 Iodo N-alkylation
#  9  0.9812  0.9257  0.9527     1.7.4 Hydroxy to methoxy
# 10  0.9938  0.9876  0.9907     1.7.6 Methyl esterification
# 11  0.9375  0.9702  0.9536     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9225  0.9634  0.9425     1.7.9 Williamson ether synthesis
# 13  0.9912  0.9814  0.9863     1.8.5 Thioether synthesis
# 14  0.9263  0.9636  0.9446    10.1.1 Bromination
# 15  0.9613  0.9710  0.9661    10.1.2 Chlorination
# 16  0.9788  0.9526  0.9655    10.1.5 Wohl-Ziegler bromination
# 17  0.9875  0.9975  0.9925    10.2.1 Nitration
# 18  0.7013  0.8919  0.7852    10.4.2 Methylation
# 19  0.9812  0.9214  0.9504     2.1.1 Amide Schotten-Baumann
# 20  0.9663  0.9520  0.9591     2.1.2 Carboxylic acid + amine reaction
# 21  0.9325  0.9777  0.9546     2.1.7 N-acetylation
# 22  0.9950  0.9938  0.9944     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9938  0.9938  0.9938     2.3.1 Isocyanate + amine reaction
# 24  0.9788  0.9899  0.9843     2.6.1 Ester Schotten-Baumann
# 25  0.9938  0.9743  0.9839     2.6.3 Fischer-Speier esterification
# 26  0.9962  0.9950  0.9956     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.8287  0.8655  0.8467     3.1.1 Bromo Suzuki coupling
# 28  0.8500  0.8553  0.8527     3.1.5 Bromo Suzuki-type coupling
# 29  0.9812  0.9987  0.9899     3.1.6 Chloro Suzuki-type coupling
# 30  0.9975  0.9767  0.9870     3.3.1 Sonogashira coupling
# 31  0.9363  0.9791  0.9572     3.4.1 Stille reaction
# 32  0.9613  0.9987  0.9796     5.1.1 N-Boc protection
# 33  0.9975  0.9901  0.9938     6.1.1 N-Boc deprotection
# 34  1.0000  0.9963  0.9981     6.1.3 N-Cbz deprotection
# 35  0.9938  0.9578  0.9755     6.1.5 N-Bn deprotection
# 36  0.9938  0.9791  0.9864     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9779  0.9864     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9988  0.9988     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9816  0.9907     6.3.1 O-Bn deprotection
# 40  0.9900  0.9826  0.9863     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9803  0.9888     7.1.1 Nitro to amino
# 42  1.0000  0.9709  0.9852     7.2.1 Amide to amine reduction
# 43  0.9988  0.9950  0.9969     7.3.1 Nitrile reduction
# 44  0.9975  0.9901  0.9938     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9950  0.9864  0.9907     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9988  0.9816  0.9901     8.1.5 Alcohol to ketone oxidation
# 47  0.9925  0.9937  0.9931     8.2.1 Sulfanyl to sulfinyl
# 48  0.9600  0.9910  0.9752     9.1.6 Hydroxy to chloro
# 49  0.9825  0.9776  0.9800     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.96    0.96    0.96

# %%
utilsFunctions.labelled_cmat(cmat_rFP_agentDictBased,rtypes,figsize=(16,12),labelExtras=names_rTypes)
