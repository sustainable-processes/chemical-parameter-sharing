# %% [markdown]
# ### Learning reaction types using different ML methods (RF, NB) and more local difference fingerprints (AP3, MG2, TT)

# %% [markdown]
# Goal: find the best/simplest/most appropriate ML model for our FPs

# %%
import cPickle,gzip
from collections import defaultdict
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
import utilsFunctions
# Out:
# /usr/prog/python/2.7.5/lib/python2.7/site-packages/nose/plugins/manager.py:418: UserWarning: Module argparse was already imported from /usr/prog/python/2.7.5/lib/python2.7/argparse.pyc, but /usr/prog/python/2.7.5/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Choose some larger text size in the plots

# %%
rcParams.update({'font.size': 14})

# %%
dataDir = "../data/"
reaction_types = cPickle.load(file(dataDir+"reactionTypes_training_test_set_patent_data.pkl"))
names_rTypes = cPickle.load(file(dataDir+"names_rTypes_classes_superclasses_training_test_set_patent_data.pkl"))

# %% [markdown]
# Load the different FPs (AP3, MG2, TT)

# %%
infile = gzip.open(dataDir+"transformationFPs_test_set_patent_data.pkl.gz", 'rb')

lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_AP3,fp_MG2,fp_TT = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_AP3,fp_MG2,fp_TT])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %% [markdown]
# Split the FPs in training (20 %) and test data (80 %) per recation type (200, 800).
# Build the "positive" version of the difference transformation fingerprints.

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=2048
#fpsz=4096
trainFps_fp_AP3=[]
trainFps_fp_MG2=[]
trainFps_fp_TT=[]
trainActs=[]
testFps_fp_AP3=[]
testFps_fp_MG2=[]
testFps_fp_TT=[]
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        trfp_AP3 = utilsFunctions.hashFP(fps[x][3],fpsz)
        trfp_AP3 = utilsFunctions.removeNegativeCountsFP(trfp_AP3)
        trainFps_fp_AP3 += [utilsFunctions.hashedFPToNP(trfp_AP3,fpsz*2)]
        trfp_MG2 = utilsFunctions.hashFP(fps[x][4],fpsz)
        trfp_MG2 = utilsFunctions.removeNegativeCountsFP(trfp_MG2)
        trainFps_fp_MG2 += [utilsFunctions.hashedFPToNP(trfp_MG2,fpsz*2)]
        trfp_TT = utilsFunctions.hashFP(fps[x][5],fpsz)
        trfp_TT = utilsFunctions.removeNegativeCountsFP(trfp_TT)
        trainFps_fp_TT += [utilsFunctions.hashedFPToNP(trfp_TT,fpsz*2)]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        tefp_AP3 = utilsFunctions.hashFP(fps[x][3],fpsz)
        tefp_AP3 = utilsFunctions.removeNegativeCountsFP(tefp_AP3)
        testFps_fp_AP3 += [utilsFunctions.hashedFPToNP(tefp_AP3,fpsz*2)]
        tefp_MG2 = utilsFunctions.hashFP(fps[x][4],fpsz)
        tefp_MG2 = utilsFunctions.removeNegativeCountsFP(tefp_MG2)
        testFps_fp_MG2 += [utilsFunctions.hashedFPToNP(tefp_MG2,fpsz*2)]
        tefp_TT = utilsFunctions.hashFP(fps[x][5],fpsz)
        tefp_TT = utilsFunctions.removeNegativeCountsFP(tefp_TT)
        testFps_fp_TT += [utilsFunctions.hashedFPToNP(tefp_TT,fpsz*2)]
    testActs += [i]*nTest
# Out:
# building fp collection

# %% [markdown]
# Build the multinomial NB classifer with the "positive" version of the FPs

# %%
print 'training models'
clf_AP3 = MultinomialNB(alpha=0.0001)
res_NB_AP3 = clf_AP3.fit(trainFps_fp_AP3, trainActs)
clf_MG2 = MultinomialNB(alpha=0.0001)
res_NB_MG2 = clf_MG2.fit(trainFps_fp_MG2, trainActs)
clf_TT = MultinomialNB(alpha=0.0001)
res_NB_TT = clf_TT.fit(trainFps_fp_TT, trainActs)
# Out:
# training models

# %% [markdown]
# Evaluate the classifier

# %%
cmat_NB_fp_AP3 = utilsFunctions.evaluateModel(res_NB_AP3, testFps_fp_AP3, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9862  0.9599  0.9729     1.2.1 Aldehyde reductive amination
#  1  0.9600  0.9552  0.9576     1.2.4 Eschweiler-Clarke methylation
#  2  0.9712  0.9737  0.9725     1.2.5 Ketone reductive amination
#  3  0.9625  0.9542  0.9583     1.3.6 Bromo N-arylation
#  4  0.9200  0.9098  0.9149     1.3.7 Chloro N-arylation
#  5  0.9812  0.9862  0.9837     1.3.8 Fluoro N-arylation
#  6  0.9275  0.9674  0.9470     1.6.2 Bromo N-alkylation
#  7  0.8788  0.8251  0.8511     1.6.4 Chloro N-alkylation
#  8  0.8838  0.8192  0.8503     1.6.8 Iodo N-alkylation
#  9  0.9500  0.9314  0.9406     1.7.4 Hydroxy to methoxy
# 10  0.8988  0.6290  0.7401     1.7.6 Methyl esterification
# 11  0.8788  0.9723  0.9232     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9675  0.9405  0.9538     1.7.9 Williamson ether synthesis
# 13  0.9862  0.9729  0.9795     1.8.5 Thioether synthesis
# 14  0.8350  0.9422  0.8854    10.1.1 Bromination
# 15  0.9287  0.9725  0.9501    10.1.2 Chlorination
# 16  0.9675  0.8716  0.9171    10.1.5 Wohl-Ziegler bromination
# 17  0.9675  0.9949  0.9810    10.2.1 Nitration
# 18  0.6600  0.5733  0.6136    10.4.2 Methylation
# 19  0.8700  0.9110  0.8900     2.1.1 Amide Schotten-Baumann
# 20  0.9413  0.9508  0.9460     2.1.2 Carboxylic acid + amine reaction
# 21  0.9613  0.9834  0.9722     2.1.7 N-acetylation
# 22  0.9900  0.9912  0.9906     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9912  0.9950  0.9931     2.3.1 Isocyanate + amine reaction
# 24  0.9625  0.9333  0.9477     2.6.1 Ester Schotten-Baumann
# 25  0.4700  0.8246  0.5987     2.6.3 Fischer-Speier esterification
# 26  0.9950  0.9888  0.9919     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.7087  0.5390  0.6123     3.1.1 Bromo Suzuki coupling
# 28  0.3762  0.5788  0.4561     3.1.5 Bromo Suzuki-type coupling
# 29  0.9625  0.9987  0.9803     3.1.6 Chloro Suzuki-type coupling
# 30  0.9938  0.9876  0.9907     3.3.1 Sonogashira coupling
# 31  0.9637  0.9625  0.9631     3.4.1 Stille reaction
# 32  0.9688  0.9936  0.9810     5.1.1 N-Boc protection
# 33  0.9975  0.9950  0.9963     6.1.1 N-Boc deprotection
# 34  1.0000  0.9756  0.9877     6.1.3 N-Cbz deprotection
# 35  0.9675  0.9949  0.9810     6.1.5 N-Bn deprotection
# 36  0.9925  0.9987  0.9956     6.2.1 CO2H-Et deprotection
# 37  0.9912  0.9694  0.9802     6.2.2 CO2H-Me deprotection
# 38  0.9962  1.0000  0.9981     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.9925  0.9950     6.3.1 O-Bn deprotection
# 40  0.9712  0.9974  0.9842     6.3.7 Methoxy to hydroxy
# 41  0.9975  1.0000  0.9987     7.1.1 Nitro to amino
# 42  0.9925  0.9937  0.9931     7.2.1 Amide to amine reduction
# 43  0.9975  0.9975  0.9975     7.3.1 Nitrile reduction
# 44  0.9962  0.9975  0.9969     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9938  0.9888  0.9913     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9938  1.0000  0.9969     8.1.5 Alcohol to ketone oxidation
# 47  0.9900  1.0000  0.9950     8.2.1 Sulfanyl to sulfinyl
# 48  0.9575  0.9884  0.9727     9.1.6 Hydroxy to chloro
# 49  0.9750  0.9726  0.9738     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.93    0.93    0.93

# %%
cmat_NB_fp_MG2 = utilsFunctions.evaluateModel(res_NB_MG2, testFps_fp_MG2, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9038  0.8981  0.9009     1.2.1 Aldehyde reductive amination
#  1  0.8413  0.7899  0.8148     1.2.4 Eschweiler-Clarke methylation
#  2  0.9337  0.9303  0.9320     1.2.5 Ketone reductive amination
#  3  0.8350  0.8642  0.8493     1.3.6 Bromo N-arylation
#  4  0.8562  0.9170  0.8856     1.3.7 Chloro N-arylation
#  5  0.9263  0.9059  0.9159     1.3.8 Fluoro N-arylation
#  6  0.7500  0.7435  0.7467     1.6.2 Bromo N-alkylation
#  7  0.6975  0.7275  0.7122     1.6.4 Chloro N-alkylation
#  8  0.7063  0.5713  0.6316     1.6.8 Iodo N-alkylation
#  9  0.8337  0.9448  0.8858     1.7.4 Hydroxy to methoxy
# 10  0.7500  0.7380  0.7440     1.7.6 Methyl esterification
# 11  0.7488  0.8449  0.7939     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.8712  0.7911  0.8293     1.7.9 Williamson ether synthesis
# 13  0.9637  0.9759  0.9698     1.8.5 Thioether synthesis
# 14  0.7987  0.8213  0.8099    10.1.1 Bromination
# 15  0.8100  0.7798  0.7946    10.1.2 Chlorination
# 16  0.8950  0.9624  0.9275    10.1.5 Wohl-Ziegler bromination
# 17  0.9475  0.9301  0.9387    10.2.1 Nitration
# 18  0.6438  0.4137  0.5037    10.4.2 Methylation
# 19  0.8612  0.9114  0.8856     2.1.1 Amide Schotten-Baumann
# 20  0.8662  0.9094  0.8873     2.1.2 Carboxylic acid + amine reaction
# 21  0.9525  0.9501  0.9513     2.1.7 N-acetylation
# 22  0.9200  0.9906  0.9540     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9912  0.9863  0.9888     2.3.1 Isocyanate + amine reaction
# 24  0.9437  0.9010  0.9219     2.6.1 Ester Schotten-Baumann
# 25  0.7250  0.7436  0.7342     2.6.3 Fischer-Speier esterification
# 26  0.9775  0.9936  0.9855     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5563  0.5583  0.5573     3.1.1 Bromo Suzuki coupling
# 28  0.5675  0.5577  0.5626     3.1.5 Bromo Suzuki-type coupling
# 29  0.9050  0.9945  0.9476     3.1.6 Chloro Suzuki-type coupling
# 30  0.9912  0.9912  0.9912     3.3.1 Sonogashira coupling
# 31  0.9500  0.9781  0.9639     3.4.1 Stille reaction
# 32  0.9725  0.9713  0.9719     5.1.1 N-Boc protection
# 33  0.9912  0.9900  0.9906     6.1.1 N-Boc deprotection
# 34  0.9988  0.9744  0.9864     6.1.3 N-Cbz deprotection
# 35  0.9663  0.9974  0.9816     6.1.5 N-Bn deprotection
# 36  0.9938  0.9913  0.9925     6.2.1 CO2H-Et deprotection
# 37  0.9650  0.9872  0.9760     6.2.2 CO2H-Me deprotection
# 38  0.9950  0.9975  0.9962     6.2.3 CO2H-tBu deprotection
# 39  0.9938  0.9962  0.9950     6.3.1 O-Bn deprotection
# 40  0.9825  0.9949  0.9887     6.3.7 Methoxy to hydroxy
# 41  0.9962  1.0000  0.9981     7.1.1 Nitro to amino
# 42  0.9363  0.9603  0.9481     7.2.1 Amide to amine reduction
# 43  0.9825  0.9987  0.9905     7.3.1 Nitrile reduction
# 44  0.9125  0.9918  0.9505     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9600  0.9987  0.9790     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9337  0.9664  0.9498     8.1.5 Alcohol to ketone oxidation
# 47  0.9700  0.9961  0.9829     8.2.1 Sulfanyl to sulfinyl
# 48  0.9425  0.9908  0.9660     9.1.6 Hydroxy to chloro
# 49  0.9800  0.9924  0.9862     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.89    0.90    0.89

# %%
cmat_NB_fp_TT = utilsFunctions.evaluateModel(res_NB_TT, testFps_fp_TT, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9087  0.8309  0.8681     1.2.1 Aldehyde reductive amination
#  1  0.7588  0.6729  0.7133     1.2.4 Eschweiler-Clarke methylation
#  2  0.9587  0.8836  0.9197     1.2.5 Ketone reductive amination
#  3  0.8925  0.7960  0.8415     1.3.6 Bromo N-arylation
#  4  0.8625  0.8984  0.8801     1.3.7 Chloro N-arylation
#  5  0.9487  0.9025  0.9250     1.3.8 Fluoro N-arylation
#  6  0.6475  0.6771  0.6620     1.6.2 Bromo N-alkylation
#  7  0.6512  0.7573  0.7003     1.6.4 Chloro N-alkylation
#  8  0.6825  0.6163  0.6477     1.6.8 Iodo N-alkylation
#  9  0.8462  0.9274  0.8850     1.7.4 Hydroxy to methoxy
# 10  0.9600  0.6095  0.7456     1.7.6 Methyl esterification
# 11  0.7013  0.8107  0.7520     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.8425  0.7423  0.7892     1.7.9 Williamson ether synthesis
# 13  0.9750  0.9432  0.9588     1.8.5 Thioether synthesis
# 14  0.7788  0.8197  0.7987    10.1.1 Bromination
# 15  0.8087  0.8469  0.8274    10.1.2 Chlorination
# 16  0.9537  0.8573  0.9030    10.1.5 Wohl-Ziegler bromination
# 17  0.9400  0.9148  0.9273    10.2.1 Nitration
# 18  0.4725  0.5377  0.5030    10.4.2 Methylation
# 19  0.6913  0.7900  0.7373     2.1.1 Amide Schotten-Baumann
# 20  0.8225  0.8194  0.8210     2.1.2 Carboxylic acid + amine reaction
# 21  0.8688  0.9097  0.8887     2.1.7 N-acetylation
# 22  0.9500  0.9645  0.9572     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9850  0.9415  0.9627     2.3.1 Isocyanate + amine reaction
# 24  0.8838  0.8397  0.8611     2.6.1 Ester Schotten-Baumann
# 25  0.3550  0.8091  0.4935     2.6.3 Fischer-Speier esterification
# 26  0.9925  0.9707  0.9815     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6825  0.5493  0.6087     3.1.1 Bromo Suzuki coupling
# 28  0.4338  0.5922  0.5007     3.1.5 Bromo Suzuki-type coupling
# 29  0.9537  0.9845  0.9689     3.1.6 Chloro Suzuki-type coupling
# 30  0.9925  0.9863  0.9894     3.3.1 Sonogashira coupling
# 31  0.9250  0.9763  0.9499     3.4.1 Stille reaction
# 32  0.9750  0.9308  0.9524     5.1.1 N-Boc protection
# 33  0.9862  0.9789  0.9826     6.1.1 N-Boc deprotection
# 34  0.9975  0.9477  0.9720     6.1.3 N-Cbz deprotection
# 35  0.9500  0.9883  0.9688     6.1.5 N-Bn deprotection
# 36  0.9725  0.9786  0.9755     6.2.1 CO2H-Et deprotection
# 37  0.9575  0.9846  0.9708     6.2.2 CO2H-Me deprotection
# 38  0.9938  1.0000  0.9969     6.2.3 CO2H-tBu deprotection
# 39  0.9962  0.9649  0.9803     6.3.1 O-Bn deprotection
# 40  0.9750  0.9873  0.9811     6.3.7 Methoxy to hydroxy
# 41  0.9788  1.0000  0.9893     7.1.1 Nitro to amino
# 42  0.9875  0.9394  0.9628     7.2.1 Amide to amine reduction
# 43  0.9625  0.9935  0.9778     7.3.1 Nitrile reduction
# 44  0.9513  0.9896  0.9700     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9525  0.9732  0.9627     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9788  0.9411  0.9596     8.1.5 Alcohol to ketone oxidation
# 47  0.9862  0.9925  0.9893     8.2.1 Sulfanyl to sulfinyl
# 48  0.8475  0.9826  0.9101     9.1.6 Hydroxy to chloro
# 49  0.9563  0.9262  0.9410     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.87    0.87    0.87

# %% [markdown]
# Draw the confusion matrices

# %%
utilsFunctions.labelled_cmat(cmat_NB_fp_AP3,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %%
utilsFunctions.labelled_cmat(cmat_NB_fp_MG2,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %%
utilsFunctions.labelled_cmat(cmat_NB_fp_TT,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %% [markdown]
# #### Test the "positive" version of the FPs with RF classifiers (max tree depth = 25)

# %%
print 'training models'
rf_cls_AP3 = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_fp_AP3 = rf_cls_AP3.fit(trainFps_fp_AP3,trainActs)
rf_cls_MG2 = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_fp_MG2 = rf_cls_MG2.fit(trainFps_fp_MG2,trainActs)
rf_cls_TT = RandomForestClassifier(n_estimators=200, max_depth=25,random_state=23,n_jobs=1)
result_rf_fp_TT = rf_cls_TT.fit(trainFps_fp_TT,trainActs)
# Out:
# training models

# %% [markdown]
# Evalutate the RF classifier using our test data

# %%
cmat_fp_AP3 = utilsFunctions.evaluateModel(result_rf_fp_AP3, testFps_fp_AP3, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9850  0.9838  0.9844     1.2.1 Aldehyde reductive amination
#  1  0.9938  0.8983  0.9436     1.2.4 Eschweiler-Clarke methylation
#  2  0.9888  0.9658  0.9771     1.2.5 Ketone reductive amination
#  3  0.9800  0.9412  0.9602     1.3.6 Bromo N-arylation
#  4  0.9812  0.9458  0.9632     1.3.7 Chloro N-arylation
#  5  0.9900  0.9754  0.9826     1.3.8 Fluoro N-arylation
#  6  0.9375  0.9804  0.9585     1.6.2 Bromo N-alkylation
#  7  0.9200  0.9710  0.9448     1.6.4 Chloro N-alkylation
#  8  0.9062  0.8529  0.8788     1.6.8 Iodo N-alkylation
#  9  0.9838  0.9448  0.9639     1.7.4 Hydroxy to methoxy
# 10  0.8462  0.7343  0.7863     1.7.6 Methyl esterification
# 11  0.9513  0.9731  0.9621     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9425  0.9729  0.9575     1.7.9 Williamson ether synthesis
# 13  0.9938  0.9827  0.9882     1.8.5 Thioether synthesis
# 14  0.9337  0.9651  0.9492    10.1.1 Bromination
# 15  0.9613  0.9747  0.9679    10.1.2 Chlorination
# 16  0.9712  0.9522  0.9616    10.1.5 Wohl-Ziegler bromination
# 17  0.9925  0.9962  0.9944    10.2.1 Nitration
# 18  0.7163  0.9183  0.8048    10.4.2 Methylation
# 19  0.9775  0.9537  0.9654     2.1.1 Amide Schotten-Baumann
# 20  0.9788  0.9596  0.9691     2.1.2 Carboxylic acid + amine reaction
# 21  0.9400  0.9779  0.9586     2.1.7 N-acetylation
# 22  0.9975  0.9925  0.9950     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9938  0.9938  0.9938     2.3.1 Isocyanate + amine reaction
# 24  0.9788  0.9861  0.9824     2.6.1 Ester Schotten-Baumann
# 25  0.6863  0.7980  0.7379     2.6.3 Fischer-Speier esterification
# 26  0.9975  0.9975  0.9975     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6262  0.5655  0.5943     3.1.1 Bromo Suzuki coupling
# 28  0.4950  0.6037  0.5440     3.1.5 Bromo Suzuki-type coupling
# 29  0.9800  0.9962  0.9880     3.1.6 Chloro Suzuki-type coupling
# 30  0.9975  0.9767  0.9870     3.3.1 Sonogashira coupling
# 31  0.9587  0.9648  0.9618     3.4.1 Stille reaction
# 32  0.9650  1.0000  0.9822     5.1.1 N-Boc protection
# 33  0.9988  0.9913  0.9950     6.1.1 N-Boc deprotection
# 34  1.0000  0.9975  0.9988     6.1.3 N-Cbz deprotection
# 35  0.9938  0.9743  0.9839     6.1.5 N-Bn deprotection
# 36  0.9950  0.9803  0.9876     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9851  0.9900     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9988  0.9988     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.9864  0.9919     6.3.1 O-Bn deprotection
# 40  0.9975  0.9791  0.9882     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9888  0.9932     7.1.1 Nitro to amino
# 42  1.0000  0.9685  0.9840     7.2.1 Amide to amine reduction
# 43  0.9988  0.9975  0.9981     7.3.1 Nitrile reduction
# 44  0.9975  0.9828  0.9901     7.9.2 Carboxylic acid to alcohol reduction
# 45  1.0000  0.9938  0.9969     8.1.4 Alcohol to aldehyde oxidation
# 46  1.0000  0.9721  0.9858     8.1.5 Alcohol to ketone oxidation
# 47  0.9925  0.9975  0.9950     8.2.1 Sulfanyl to sulfinyl
# 48  0.9762  0.9924  0.9842     9.1.6 Hydroxy to chloro
# 49  0.9825  0.9862  0.9843     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.95    0.95    0.95

# %%
cmat_fp_MG2 = utilsFunctions.evaluateModel(result_rf_fp_MG2, testFps_fp_MG2, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9888  0.9576  0.9729     1.2.1 Aldehyde reductive amination
#  1  0.9400  0.8430  0.8889     1.2.4 Eschweiler-Clarke methylation
#  2  0.9800  0.9763  0.9782     1.2.5 Ketone reductive amination
#  3  0.9762  0.8895  0.9309     1.3.6 Bromo N-arylation
#  4  0.9825  0.9247  0.9527     1.3.7 Chloro N-arylation
#  5  0.9900  0.9395  0.9641     1.3.8 Fluoro N-arylation
#  6  0.9350  0.9803  0.9571     1.6.2 Bromo N-alkylation
#  7  0.8925  0.9688  0.9291     1.6.4 Chloro N-alkylation
#  8  0.8738  0.9054  0.8893     1.6.8 Iodo N-alkylation
#  9  0.9712  0.9184  0.9441     1.7.4 Hydroxy to methoxy
# 10  0.8037  0.7861  0.7948     1.7.6 Methyl esterification
# 11  0.9487  0.9756  0.9620     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9125  0.9799  0.9450     1.7.9 Williamson ether synthesis
# 13  0.9938  0.9498  0.9713     1.8.5 Thioether synthesis
# 14  0.9263  0.9636  0.9446    10.1.1 Bromination
# 15  0.9350  0.9565  0.9456    10.1.2 Chlorination
# 16  0.9775  0.9456  0.9613    10.1.5 Wohl-Ziegler bromination
# 17  0.9888  0.9937  0.9912    10.2.1 Nitration
# 18  0.6025  0.8909  0.7189    10.4.2 Methylation
# 19  0.9775  0.9114  0.9433     2.1.1 Amide Schotten-Baumann
# 20  0.9700  0.9510  0.9604     2.1.2 Carboxylic acid + amine reaction
# 21  0.9437  0.9792  0.9612     2.1.7 N-acetylation
# 22  0.9888  0.9950  0.9918     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9938  0.9950  0.9944     2.3.1 Isocyanate + amine reaction
# 24  0.9688  0.9798  0.9742     2.6.1 Ester Schotten-Baumann
# 25  0.7963  0.7884  0.7923     2.6.3 Fischer-Speier esterification
# 26  0.9975  0.9963  0.9969     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6212  0.5847  0.6024     3.1.1 Bromo Suzuki coupling
# 28  0.5350  0.6203  0.5745     3.1.5 Bromo Suzuki-type coupling
# 29  0.9812  0.9912  0.9862     3.1.6 Chloro Suzuki-type coupling
# 30  0.9975  0.9767  0.9870     3.3.1 Sonogashira coupling
# 31  0.9275  0.9789  0.9525     3.4.1 Stille reaction
# 32  0.9563  1.0000  0.9776     5.1.1 N-Boc protection
# 33  0.9988  0.9901  0.9944     6.1.1 N-Boc deprotection
# 34  0.9988  0.9963  0.9975     6.1.3 N-Cbz deprotection
# 35  0.9962  0.9743  0.9852     6.1.5 N-Bn deprotection
# 36  0.9975  0.9568  0.9767     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9695  0.9821     6.2.2 CO2H-Me deprotection
# 38  0.9988  1.0000  0.9994     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9950  0.9975     6.3.1 O-Bn deprotection
# 40  0.9888  0.9706  0.9796     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9840  0.9907     7.1.1 Nitro to amino
# 42  0.9962  0.9454  0.9702     7.2.1 Amide to amine reduction
# 43  0.9988  0.9938  0.9963     7.3.1 Nitrile reduction
# 44  0.9975  0.9901  0.9938     7.9.2 Carboxylic acid to alcohol reduction
# 45  1.0000  0.9889  0.9944     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9988  0.9627  0.9804     8.1.5 Alcohol to ketone oxidation
# 47  0.9862  0.9887  0.9875     8.2.1 Sulfanyl to sulfinyl
# 48  0.9500  0.9845  0.9669     9.1.6 Hydroxy to chloro
# 49  0.9888  0.9729  0.9808     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.94    0.94    0.94

# %%
cmat_fp_TT = utilsFunctions.evaluateModel(result_rf_fp_TT, testFps_fp_TT, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.8025  0.8447  0.8231     1.2.1 Aldehyde reductive amination
#  1  0.9113  0.7305  0.8109     1.2.4 Eschweiler-Clarke methylation
#  2  0.8962  0.8308  0.8623     1.2.5 Ketone reductive amination
#  3  0.9038  0.8216  0.8607     1.3.6 Bromo N-arylation
#  4  0.9400  0.8346  0.8842     1.3.7 Chloro N-arylation
#  5  0.9762  0.9177  0.9461     1.3.8 Fluoro N-arylation
#  6  0.5625  0.7075  0.6267     1.6.2 Bromo N-alkylation
#  7  0.5038  0.6972  0.5849     1.6.4 Chloro N-alkylation
#  8  0.6150  0.5816  0.5978     1.6.8 Iodo N-alkylation
#  9  0.7612  0.8878  0.8197     1.7.4 Hydroxy to methoxy
# 10  0.9875  0.6191  0.7611     1.7.6 Methyl esterification
# 11  0.7837  0.7857  0.7847     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.5750  0.9256  0.7093     1.7.9 Williamson ether synthesis
# 13  0.8225  0.9522  0.8826     1.8.5 Thioether synthesis
# 14  0.8263  0.9005  0.8618    10.1.1 Bromination
# 15  0.7325  0.9029  0.8088    10.1.2 Chlorination
# 16  0.9113  0.8506  0.8799    10.1.5 Wohl-Ziegler bromination
# 17  0.9575  0.9399  0.9486    10.2.1 Nitration
# 18  0.2787  0.7770  0.4103    10.4.2 Methylation
# 19  0.7037  0.7712  0.7359     2.1.1 Amide Schotten-Baumann
# 20  0.7837  0.7808  0.7823     2.1.2 Carboxylic acid + amine reaction
# 21  0.9062  0.9771  0.9403     2.1.7 N-acetylation
# 22  0.9563  0.8958  0.9250     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9825  0.9668  0.9746     2.3.1 Isocyanate + amine reaction
# 24  0.9100  0.8080  0.8560     2.6.1 Ester Schotten-Baumann
# 25  0.3762  0.8247  0.5167     2.6.3 Fischer-Speier esterification
# 26  0.9900  0.9766  0.9832     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5737  0.5356  0.5540     3.1.1 Bromo Suzuki coupling
# 28  0.4512  0.5545  0.4976     3.1.5 Bromo Suzuki-type coupling
# 29  0.9587  0.9098  0.9337     3.1.6 Chloro Suzuki-type coupling
# 30  0.9862  0.9315  0.9581     3.3.1 Sonogashira coupling
# 31  0.8163  0.9820  0.8915     3.4.1 Stille reaction
# 32  0.9688  0.9848  0.9767     5.1.1 N-Boc protection
# 33  0.9975  0.9840  0.9907     6.1.1 N-Boc deprotection
# 34  1.0000  0.9988  0.9994     6.1.3 N-Cbz deprotection
# 35  0.9962  0.9466  0.9708     6.1.5 N-Bn deprotection
# 36  0.9975  0.9366  0.9661     6.2.1 CO2H-Et deprotection
# 37  0.9912  0.9612  0.9760     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9650  0.9816     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9950  0.9975     6.3.1 O-Bn deprotection
# 40  0.9513  0.9407  0.9459     6.3.7 Methoxy to hydroxy
# 41  0.9725  0.9605  0.9665     7.1.1 Nitro to amino
# 42  0.9387  0.8983  0.9181     7.2.1 Amide to amine reduction
# 43  0.6162  0.9355  0.7430     7.3.1 Nitrile reduction
# 44  0.8387  0.8817  0.8597     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.8562  0.8273  0.8415     8.1.4 Alcohol to aldehyde oxidation
# 46  0.8387  0.8983  0.8675     8.1.5 Alcohol to ketone oxidation
# 47  0.9325  0.9726  0.9521     8.2.1 Sulfanyl to sulfinyl
# 48  0.8462  0.3111  0.4550     9.1.6 Hydroxy to chloro
# 49  0.7550  0.8580  0.8032     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.83    0.85    0.84

# %%
utilsFunctions.labelled_cmat(cmat_fp_AP3,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %%
utilsFunctions.labelled_cmat(cmat_fp_MG2,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %%
utilsFunctions.labelled_cmat(cmat_fp_TT,rtypes,figsize=(16,12), labelExtras=names_rTypes)
