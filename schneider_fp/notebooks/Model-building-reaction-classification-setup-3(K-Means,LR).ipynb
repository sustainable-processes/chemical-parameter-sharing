# %% [markdown]
# ### Learning reaction types using different ML methods (K-Means, LR) and more local difference fingerprints (AP3, MG2, TT)

# %% [markdown]
# Goal: find the best/simplest/most appropriate ML model for our FPs

# %%
import cPickle,gzip
from collections import defaultdict
import random
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
import utilsFunctions
# Out:
# /usr/prog/python/2.7.5/lib/python2.7/site-packages/nose/plugins/manager.py:418: UserWarning: Module argparse was already imported from /usr/prog/python/2.7.5/lib/python2.7/argparse.pyc, but /usr/prog/python/2.7.5/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %% [markdown]
# Choose some larger text size in the plots

# %%
rcParams.update({'font.size': 14})

# %%
dataDir = "../data/"
reaction_types = cPickle.load(file(dataDir+"reactionTypes_training_test_set_patent_data.pkl"))
names_rTypes = cPickle.load(file(dataDir+"names_rTypes_classes_superclasses_training_test_set_patent_data.pkl"))

# %% [markdown]
# Load the different FPs (AP3, MG2, TT)

# %%
infile = gzip.open(dataDir+"transformationFPs_test_set_patent_data.pkl.gz", 'rb')

lineNo=0
fps=[]
idx=0
while 1:
    lineNo+=1
    try:
        lbl,cls,fp_AP3,fp_MG2,fp_TT = cPickle.load(infile)        
    except EOFError:
        break
    fps.append([idx,lbl,cls,fp_AP3,fp_MG2,fp_TT])
    idx+=1
    if not lineNo%10000:
        print "Done "+str(lineNo)
# Out:
# Done 10000
# Done 20000
# Done 30000
# Done 40000
# Done 50000

# %% [markdown]
# Split the FPs in training (20 %) and test data (80 %) per recation type (200, 800)

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=2048 # the FPs bit size for converting the FPs to a numpy array
#fpsz=4096
trainFps_fp_AP3=defaultdict(list)
trainFps_fp_MG2=defaultdict(list)
trainFps_fp_TT=defaultdict(list)
trainActs=[]
testFps_fp_AP3=defaultdict(list)
testFps_fp_MG2=defaultdict(list)
testFps_fp_TT=defaultdict(list)
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        trainFps_fp_AP3[klass] += [utilsFunctions.fpToNP(fps[x][3],fpsz)]
        trainFps_fp_MG2[klass] += [utilsFunctions.fpToNP(fps[x][4],fpsz)]
        trainFps_fp_TT[klass] += [utilsFunctions.fpToNP(fps[x][5],fpsz)]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        testFps_fp_AP3[klass] += [utilsFunctions.fpToNP(fps[x][3],fpsz)]
        testFps_fp_MG2[klass] += [utilsFunctions.fpToNP(fps[x][4],fpsz)]
        testFps_fp_TT[klass] += [utilsFunctions.fpToNP(fps[x][5],fpsz)]
    testActs += [i]*nTest
# Out:
# building fp collection

# %% [markdown]
# Build the K-Means (k=3) clusters for each of the 50 reaction types and store them in a map. Here AP3 FPs were used.

# %%
print 'training model'
clusters_per_rType_AP3 = {}
for cls in trainFps_fp_AP3:
    cl = KMeans(n_clusters=3)
    res = cl.fit(trainFps_fp_AP3[cls])
    clusters_per_rType_AP3[cls] = res
# Out:
# training model

# %% [markdown]
# Evaluate the K-Means cluster using a kind of nearest neighbor approach

# %%
cmat_KM_fp_AP3 = utilsFunctions.evaluateKMeansClustering(clusters_per_rType_AP3, testFps_fp_AP3, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.8550  0.9956  0.9200     1.2.1 Aldehyde reductive amination
#  1  0.9675  0.7220  0.8269     1.2.4 Eschweiler-Clarke methylation
#  2  0.9275  0.9841  0.9550     1.2.5 Ketone reductive amination
#  3  0.8475  0.8391  0.8433     1.3.6 Bromo N-arylation
#  4  0.9125  0.8230  0.8654     1.3.7 Chloro N-arylation
#  5  0.8675  0.9666  0.9144     1.3.8 Fluoro N-arylation
#  6  0.6763  0.7017  0.6887     1.6.2 Bromo N-alkylation
#  7  0.6338  0.8191  0.7146     1.6.4 Chloro N-alkylation
#  8  0.5837  0.6596  0.6194     1.6.8 Iodo N-alkylation
#  9  0.9650  0.8373  0.8966     1.7.4 Hydroxy to methoxy
# 10  0.7212  0.6520  0.6849     1.7.6 Methyl esterification
# 11  0.5513  0.9149  0.6880     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.8363  0.7042  0.7646     1.7.9 Williamson ether synthesis
# 13  0.9688  0.9544  0.9615     1.8.5 Thioether synthesis
# 14  0.8838  0.8528  0.8680    10.1.1 Bromination
# 15  0.8462  0.9469  0.8937    10.1.2 Chlorination
# 16  0.9600  0.8562  0.9051    10.1.5 Wohl-Ziegler bromination
# 17  0.9600  0.9948  0.9771    10.2.1 Nitration
# 18  0.4875  0.4599  0.4733    10.4.2 Methylation
# 19  0.8500  0.7870  0.8173     2.1.1 Amide Schotten-Baumann
# 20  0.8812  0.8113  0.8448     2.1.2 Carboxylic acid + amine reaction
# 21  0.8900  0.9727  0.9295     2.1.7 N-acetylation
# 22  0.9637  0.9987  0.9809     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9812  0.9987  0.9899     2.3.1 Isocyanate + amine reaction
# 24  0.9363  0.8649  0.8992     2.6.1 Ester Schotten-Baumann
# 25  0.6500  0.6476  0.6488     2.6.3 Fischer-Speier esterification
# 26  0.9962  1.0000  0.9981     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5062  0.4988  0.5025     3.1.1 Bromo Suzuki coupling
# 28  0.4850  0.5236  0.5036     3.1.5 Bromo Suzuki-type coupling
# 29  0.8688  0.9392  0.9026     3.1.6 Chloro Suzuki-type coupling
# 30  0.9862  0.9950  0.9906     3.3.1 Sonogashira coupling
# 31  0.7963  0.9681  0.8738     3.4.1 Stille reaction
# 32  0.9350  0.9765  0.9553     5.1.1 N-Boc protection
# 33  0.9975  0.9913  0.9944     6.1.1 N-Boc deprotection
# 34  1.0000  0.9889  0.9944     6.1.3 N-Cbz deprotection
# 35  0.9862  0.9529  0.9693     6.1.5 N-Bn deprotection
# 36  0.9938  0.9803  0.9870     6.2.1 CO2H-Et deprotection
# 37  0.9838  0.9505  0.9668     6.2.2 CO2H-Me deprotection
# 38  0.9975  0.9828  0.9901     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.9466  0.9714     6.3.1 O-Bn deprotection
# 40  0.9637  0.9723  0.9680     6.3.7 Methoxy to hydroxy
# 41  0.9788  0.9975  0.9880     7.1.1 Nitro to amino
# 42  0.9463  0.9077  0.9266     7.2.1 Amide to amine reduction
# 43  0.9988  0.9685  0.9834     7.3.1 Nitrile reduction
# 44  0.9675  0.8795  0.9214     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9912  0.9554  0.9730     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9862  0.9975  0.9918     8.1.5 Alcohol to ketone oxidation
# 47  0.9900  1.0000  0.9950     8.2.1 Sulfanyl to sulfinyl
# 48  0.9313  0.9601  0.9454     9.1.6 Hydroxy to chloro
# 49  0.9762  0.9490  0.9624     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.88    0.88    0.88
# /home/schnenaa/venvs/ipython2/lib/python2.7/site-packages/sklearn/cluster/k_means_.py:773: RuntimeWarning: Got data type int32, converted to float to avoid overflows
#   X = self._check_test_data(X)

# %% [markdown]
# Draw the confusion matrix

# %%
utilsFunctions.labelled_cmat(cmat_KM_fp_AP3,rtypes,figsize=(16,12), labelExtras=names_rTypes, xlabel=False)

# %% [markdown]
# Build the K-Means (k=3) clusters for each of the 50 reaction types and store them in a map. Here MG2 FPs were used.

# %%
print 'training model'
clusters_per_rType_MG2 = {}
for cls in trainFps_fp_MG2:
    cl = KMeans(n_clusters=3)
    res = cl.fit(trainFps_fp_MG2[cls])
    clusters_per_rType_MG2[cls] = res
# Out:
# training model

# %%
cmat_KM_fp_MG2 = utilsFunctions.evaluateKMeansClustering(clusters_per_rType_MG2, testFps_fp_MG2, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.8925  0.9636  0.9267     1.2.1 Aldehyde reductive amination
#  1  0.7913  0.6134  0.6910     1.2.4 Eschweiler-Clarke methylation
#  2  0.9100  0.9878  0.9473     1.2.5 Ketone reductive amination
#  3  0.8575  0.7424  0.7958     1.3.6 Bromo N-arylation
#  4  0.8488  0.7877  0.8171     1.3.7 Chloro N-arylation
#  5  0.7900  0.9433  0.8599     1.3.8 Fluoro N-arylation
#  6  0.8125  0.8632  0.8371     1.6.2 Bromo N-alkylation
#  7  0.8100  0.7397  0.7733     1.6.4 Chloro N-alkylation
#  8  0.7638  0.7197  0.7411     1.6.8 Iodo N-alkylation
#  9  0.9150  0.8188  0.8642     1.7.4 Hydroxy to methoxy
# 10  0.6725  0.7797  0.7221     1.7.6 Methyl esterification
# 11  0.9250  0.9296  0.9273     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.8638  0.8758  0.8697     1.7.9 Williamson ether synthesis
# 13  0.9875  0.9394  0.9628     1.8.5 Thioether synthesis
# 14  0.8400  0.8784  0.8588    10.1.1 Bromination
# 15  0.8063  0.8921  0.8470    10.1.2 Chlorination
# 16  0.9862  0.8895  0.9354    10.1.5 Wohl-Ziegler bromination
# 17  0.9450  0.9767  0.9606    10.2.1 Nitration
# 18  0.5075  0.6024  0.5509    10.4.2 Methylation
# 19  0.7963  0.7638  0.7797     2.1.1 Amide Schotten-Baumann
# 20  0.8350  0.9076  0.8698     2.1.2 Carboxylic acid + amine reaction
# 21  0.9175  0.9645  0.9404     2.1.7 N-acetylation
# 22  0.8975  0.9958  0.9441     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9925  1.0000  0.9962     2.3.1 Isocyanate + amine reaction
# 24  0.9463  0.9718  0.9588     2.6.1 Ester Schotten-Baumann
# 25  0.8137  0.7348  0.7722     2.6.3 Fischer-Speier esterification
# 26  0.9413  0.9987  0.9691     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.5425  0.5130  0.5273     3.1.1 Bromo Suzuki coupling
# 28  0.4487  0.5279  0.4851     3.1.5 Bromo Suzuki-type coupling
# 29  0.9563  0.9909  0.9733     3.1.6 Chloro Suzuki-type coupling
# 30  0.9888  0.9912  0.9900     3.3.1 Sonogashira coupling
# 31  0.7550  0.9452  0.8395     3.4.1 Stille reaction
# 32  0.9350  0.9934  0.9633     5.1.1 N-Boc protection
# 33  0.9975  0.9913  0.9944     6.1.1 N-Boc deprotection
# 34  0.9875  0.9875  0.9875     6.1.3 N-Cbz deprotection
# 35  0.9925  0.8852  0.9358     6.1.5 N-Bn deprotection
# 36  0.9938  0.9578  0.9755     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9767  0.9858     6.2.2 CO2H-Me deprotection
# 38  0.9975  0.9355  0.9655     6.2.3 CO2H-tBu deprotection
# 39  0.9975  0.9720  0.9846     6.3.1 O-Bn deprotection
# 40  0.9850  0.9887  0.9869     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9975  0.9975     7.1.1 Nitro to amino
# 42  0.9988  0.8819  0.9367     7.2.1 Amide to amine reduction
# 43  0.9975  0.9732  0.9852     7.3.1 Nitrile reduction
# 44  0.9975  0.9828  0.9901     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9962  0.9925  0.9944     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9962  0.9864  0.9913     8.1.5 Alcohol to ketone oxidation
# 47  0.9725  0.9987  0.9854     8.2.1 Sulfanyl to sulfinyl
# 48  0.9225  0.9401  0.9312     9.1.6 Hydroxy to chloro
# 49  0.9675  0.9225  0.9445     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.89    0.89    0.89

# %%
utilsFunctions.labelled_cmat(cmat_KM_fp_MG2,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %% [markdown]
# Build the K-Means (k=3) clusters for each of the 50 reaction types and store them in a map. Here TT FPs were used.

# %%
print 'training model'
clusters_per_rType_TT = {}
for cls in trainFps_fp_TT:
    cl = KMeans(n_clusters=3)
    res = cl.fit(trainFps_fp_TT[cls])
    clusters_per_rType_TT[cls] = res
# Out:
# training model

# %%
cmat_KM_fp_TT = utilsFunctions.evaluateKMeansClustering(clusters_per_rType_TT, testFps_fp_TT, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.6850  0.7840  0.7312     1.2.1 Aldehyde reductive amination
#  1  0.8450  0.6004  0.7020     1.2.4 Eschweiler-Clarke methylation
#  2  0.8275  0.9285  0.8751     1.2.5 Ketone reductive amination
#  3  0.5100  0.5804  0.5429     1.3.6 Bromo N-arylation
#  4  0.7812  0.7135  0.7458     1.3.7 Chloro N-arylation
#  5  0.7137  0.8397  0.7716     1.3.8 Fluoro N-arylation
#  6  0.3912  0.4102  0.4005     1.6.2 Bromo N-alkylation
#  7  0.2787  0.7534  0.4069     1.6.4 Chloro N-alkylation
#  8  0.4437  0.4653  0.4543     1.6.8 Iodo N-alkylation
#  9  0.7462  0.8408  0.7907     1.7.4 Hydroxy to methoxy
# 10  0.7575  0.5560  0.6413     1.7.6 Methyl esterification
# 11  0.3850  0.6299  0.4779     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.6325  0.6278  0.6301     1.7.9 Williamson ether synthesis
# 13  0.8862  0.9739  0.9280     1.8.5 Thioether synthesis
# 14  0.6038  0.7252  0.6589    10.1.1 Bromination
# 15  0.6188  0.7477  0.6772    10.1.2 Chlorination
# 16  0.9187  0.7601  0.8319    10.1.5 Wohl-Ziegler bromination
# 17  0.9137  0.9905  0.9506    10.2.1 Nitration
# 18  0.4475  0.4027  0.4239    10.4.2 Methylation
# 19  0.5275  0.4896  0.5078     2.1.1 Amide Schotten-Baumann
# 20  0.6000  0.5575  0.5780     2.1.2 Carboxylic acid + amine reaction
# 21  0.8888  0.9753  0.9300     2.1.7 N-acetylation
# 22  0.9163  0.9361  0.9261     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.8200  0.9970  0.8999     2.3.1 Isocyanate + amine reaction
# 24  0.7688  0.7621  0.7654     2.6.1 Ester Schotten-Baumann
# 25  0.5375  0.5858  0.5606     2.6.3 Fischer-Speier esterification
# 26  0.9025  1.0000  0.9488     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.3975  0.4732  0.4321     3.1.1 Bromo Suzuki coupling
# 28  0.4988  0.4848  0.4917     3.1.5 Bromo Suzuki-type coupling
# 29  0.7588  0.7782  0.7684     3.1.6 Chloro Suzuki-type coupling
# 30  0.8925  0.9958  0.9413     3.3.1 Sonogashira coupling
# 31  0.7488  0.9884  0.8521     3.4.1 Stille reaction
# 32  0.9425  0.9767  0.9593     5.1.1 N-Boc protection
# 33  0.9675  0.9923  0.9797     6.1.1 N-Boc deprotection
# 34  0.9812  0.9987  0.9899     6.1.3 N-Cbz deprotection
# 35  0.9925  0.9464  0.9689     6.1.5 N-Bn deprotection
# 36  0.9938  0.9498  0.9713     6.2.1 CO2H-Et deprotection
# 37  0.9613  0.9436  0.9523     6.2.2 CO2H-Me deprotection
# 38  0.9975  0.9603  0.9785     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9627  0.9810     6.3.1 O-Bn deprotection
# 40  0.9113  0.9605  0.9352     6.3.7 Methoxy to hydroxy
# 41  0.9675  0.9872  0.9773     7.1.1 Nitro to amino
# 42  0.8662  0.9480  0.9053     7.2.1 Amide to amine reduction
# 43  0.7525  0.9571  0.8425     7.3.1 Nitrile reduction
# 44  0.7650  0.8384  0.8000     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.8888  0.8660  0.8772     8.1.4 Alcohol to aldehyde oxidation
# 46  0.8588  0.9745  0.9130     8.1.5 Alcohol to ketone oxidation
# 47  0.8988  0.9972  0.9454     8.2.1 Sulfanyl to sulfinyl
# 48  0.7512  0.6924  0.7206     9.1.6 Hydroxy to chloro
# 49  0.9800  0.2966  0.4554     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.76    0.79    0.78

# %%
utilsFunctions.labelled_cmat(cmat_KM_fp_TT,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %% [markdown]
# #### Test the Logistic regression classifier with all three FPs types (AP3, MG2, TT)

# %%
random.seed(0xd00f)
indices=range(len(fps))
random.shuffle(indices)

nActive=200
fpsz=2048
#fpsz=4096
trainFps_fp_AP3=[]
trainFps_fp_MG2=[]
trainFps_fp_TT=[]
trainActs=[]
testFps_fp_AP3=[]
testFps_fp_MG2=[]
testFps_fp_TT=[]
testActs=[]

print 'building fp collection'

rtypes=sorted(list(reaction_types))
for i,klass in enumerate(rtypes):
    actIds = [x for x in indices if fps[x][2]==klass]
    for x in actIds[:nActive]:
        trainFps_fp_AP3 += [utilsFunctions.fpToNP(fps[x][3],fpsz)]
        trainFps_fp_MG2 += [utilsFunctions.fpToNP(fps[x][4],fpsz)]
        trainFps_fp_TT += [utilsFunctions.fpToNP(fps[x][5],fpsz)]
    trainActs += [i]*nActive
    nTest=len(actIds)-nActive
    for x in actIds[nActive:]:
        testFps_fp_AP3 += [utilsFunctions.fpToNP(fps[x][3],fpsz)]
        testFps_fp_MG2 += [utilsFunctions.fpToNP(fps[x][4],fpsz)]
        testFps_fp_TT += [utilsFunctions.fpToNP(fps[x][5],fpsz)]
    testActs += [i]*nTest
# Out:
# building fp collection

# %% [markdown]
# Build the LR classifier without the need of parameters

# %%
print 'training models'
lr_cls_AP3 = LogisticRegression()
result_lr_fp_AP3 = lr_cls_AP3.fit(trainFps_fp_AP3,trainActs)
lr_cls_MG2 = LogisticRegression()
result_lr_fp_MG2 = lr_cls_MG2.fit(trainFps_fp_MG2,trainActs)
lr_cls_TT = LogisticRegression()
result_lr_fp_TT = lr_cls_TT.fit(trainFps_fp_TT,trainActs)
# Out:
# training models

# %% [markdown]
# Evalutate the LR classifier using our test data

# %%
cmat_fp_AP3 = utilsFunctions.evaluateModel(result_lr_fp_AP3, testFps_fp_AP3, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9825  0.9887  0.9856     1.2.1 Aldehyde reductive amination
#  1  0.9862  0.9622  0.9741     1.2.4 Eschweiler-Clarke methylation
#  2  0.9788  0.9775  0.9781     1.2.5 Ketone reductive amination
#  3  0.9712  0.9676  0.9694     1.3.6 Bromo N-arylation
#  4  0.9825  0.9621  0.9722     1.3.7 Chloro N-arylation
#  5  0.9900  0.9766  0.9832     1.3.8 Fluoro N-arylation
#  6  0.9600  0.9808  0.9703     1.6.2 Bromo N-alkylation
#  7  0.9425  0.9460  0.9443     1.6.4 Chloro N-alkylation
#  8  0.9325  0.8966  0.9142     1.6.8 Iodo N-alkylation
#  9  0.9812  0.9171  0.9481     1.7.4 Hydroxy to methoxy
# 10  0.7762  0.8182  0.7967     1.7.6 Methyl esterification
# 11  0.9537  0.9757  0.9646     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9625  0.9649  0.9637     1.7.9 Williamson ether synthesis
# 13  0.9838  0.9949  0.9893     1.8.5 Thioether synthesis
# 14  0.9337  0.9589  0.9462    10.1.1 Bromination
# 15  0.9363  0.9677  0.9517    10.1.2 Chlorination
# 16  0.9712  0.9441  0.9575    10.1.5 Wohl-Ziegler bromination
# 17  0.9900  0.9975  0.9937    10.2.1 Nitration
# 18  0.7125  0.8297  0.7666    10.4.2 Methylation
# 19  0.9912  0.9520  0.9712     2.1.1 Amide Schotten-Baumann
# 20  0.9700  0.9604  0.9652     2.1.2 Carboxylic acid + amine reaction
# 21  0.9663  0.9614  0.9638     2.1.7 N-acetylation
# 22  0.9962  0.9962  0.9962     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9925  0.9987  0.9956     2.3.1 Isocyanate + amine reaction
# 24  0.9850  0.9813  0.9832     2.6.1 Ester Schotten-Baumann
# 25  0.8175  0.7730  0.7947     2.6.3 Fischer-Speier esterification
# 26  0.9962  1.0000  0.9981     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6425  0.5486  0.5918     3.1.1 Bromo Suzuki coupling
# 28  0.4450  0.5846  0.5053     3.1.5 Bromo Suzuki-type coupling
# 29  0.9838  0.9937  0.9887     3.1.6 Chloro Suzuki-type coupling
# 30  0.9938  0.9888  0.9913     3.3.1 Sonogashira coupling
# 31  0.9750  0.9738  0.9744     3.4.1 Stille reaction
# 32  0.9625  0.9974  0.9796     5.1.1 N-Boc protection
# 33  0.9988  0.9938  0.9963     6.1.1 N-Boc deprotection
# 34  0.9988  0.9963  0.9975     6.1.3 N-Cbz deprotection
# 35  0.9925  0.9900  0.9913     6.1.5 N-Bn deprotection
# 36  0.9962  0.9602  0.9779     6.2.1 CO2H-Et deprotection
# 37  0.9938  0.9731  0.9833     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9913  0.9950     6.2.3 CO2H-tBu deprotection
# 39  0.9988  0.9938  0.9963     6.3.1 O-Bn deprotection
# 40  0.9962  0.9913  0.9938     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9925  0.9950     7.1.1 Nitro to amino
# 42  1.0000  0.9804  0.9901     7.2.1 Amide to amine reduction
# 43  0.9975  0.9987  0.9981     7.3.1 Nitrile reduction
# 44  0.9975  0.9925  0.9950     7.9.2 Carboxylic acid to alcohol reduction
# 45  1.0000  0.9926  0.9963     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9962  0.9950  0.9956     8.1.5 Alcohol to ketone oxidation
# 47  0.9925  0.9962  0.9944     8.2.1 Sulfanyl to sulfinyl
# 48  0.9825  0.9644  0.9734     9.1.6 Hydroxy to chloro
# 49  0.9762  0.9936  0.9849     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.95    0.95    0.95

# %%
utilsFunctions.labelled_cmat(cmat_fp_AP3,rtypes,figsize=(16,12), labelExtras=names_rTypes)

# %%
cmat_fp_MG2 = utilsFunctions.evaluateModel(result_lr_fp_MG2, testFps_fp_MG2, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9788  0.9837  0.9812     1.2.1 Aldehyde reductive amination
#  1  0.9663  0.9062  0.9353     1.2.4 Eschweiler-Clarke methylation
#  2  0.9788  0.9619  0.9703     1.2.5 Ketone reductive amination
#  3  0.9637  0.9368  0.9501     1.3.6 Bromo N-arylation
#  4  0.9775  0.9321  0.9542     1.3.7 Chloro N-arylation
#  5  0.9900  0.9659  0.9778     1.3.8 Fluoro N-arylation
#  6  0.9525  0.9719  0.9621     1.6.2 Bromo N-alkylation
#  7  0.9150  0.9397  0.9272     1.6.4 Chloro N-alkylation
#  8  0.9087  0.8986  0.9037     1.6.8 Iodo N-alkylation
#  9  0.9663  0.9291  0.9473     1.7.4 Hydroxy to methoxy
# 10  0.7825  0.7914  0.7869     1.7.6 Methyl esterification
# 11  0.9563  0.9574  0.9568     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.9350  0.9504  0.9427     1.7.9 Williamson ether synthesis
# 13  0.9888  0.9814  0.9851     1.8.5 Thioether synthesis
# 14  0.9038  0.9563  0.9293    10.1.1 Bromination
# 15  0.8675  0.9278  0.8966    10.1.2 Chlorination
# 16  0.9838  0.9358  0.9592    10.1.5 Wohl-Ziegler bromination
# 17  0.9800  0.9962  0.9880    10.2.1 Nitration
# 18  0.6338  0.7824  0.7003    10.4.2 Methylation
# 19  0.9812  0.9412  0.9608     2.1.1 Amide Schotten-Baumann
# 20  0.9637  0.9759  0.9698     2.1.2 Carboxylic acid + amine reaction
# 21  0.9563  0.9758  0.9659     2.1.7 N-acetylation
# 22  0.9925  0.9913  0.9919     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9938  0.9962  0.9950     2.3.1 Isocyanate + amine reaction
# 24  0.9750  0.9665  0.9708     2.6.1 Ester Schotten-Baumann
# 25  0.8075  0.7700  0.7883     2.6.3 Fischer-Speier esterification
# 26  0.9950  0.9987  0.9969     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.4575  0.5438  0.4969     3.1.1 Bromo Suzuki coupling
# 28  0.5975  0.5347  0.5643     3.1.5 Bromo Suzuki-type coupling
# 29  0.9812  0.9962  0.9887     3.1.6 Chloro Suzuki-type coupling
# 30  0.9975  0.9950  0.9963     3.3.1 Sonogashira coupling
# 31  0.9712  0.9885  0.9798     3.4.1 Stille reaction
# 32  0.9513  0.9961  0.9731     5.1.1 N-Boc protection
# 33  0.9988  0.9889  0.9938     6.1.1 N-Boc deprotection
# 34  0.9988  0.9988  0.9988     6.1.3 N-Cbz deprotection
# 35  0.9962  0.9901  0.9931     6.1.5 N-Bn deprotection
# 36  0.9975  0.9568  0.9767     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9731  0.9839     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9901  0.9944     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9938  0.9969     6.3.1 O-Bn deprotection
# 40  0.9875  0.9826  0.9850     6.3.7 Methoxy to hydroxy
# 41  0.9975  0.9888  0.9932     7.1.1 Nitro to amino
# 42  0.9988  0.9557  0.9768     7.2.1 Amide to amine reduction
# 43  0.9988  0.9963  0.9975     7.3.1 Nitrile reduction
# 44  0.9975  0.9864  0.9919     7.9.2 Carboxylic acid to alcohol reduction
# 45  1.0000  0.9889  0.9944     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9975  0.9803  0.9888     8.1.5 Alcohol to ketone oxidation
# 47  0.9900  0.9962  0.9931     8.2.1 Sulfanyl to sulfinyl
# 48  0.9475  0.9755  0.9613     9.1.6 Hydroxy to chloro
# 49  0.9788  0.9775  0.9781     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.94    0.94    0.94

# %%
utilsFunctions.labelled_cmat(cmat_fp_MG2,rtypes,figsize=(16,12),labelExtras=names_rTypes)

# %%
cmat_fp_TT = utilsFunctions.evaluateModel(result_lr_fp_TT, testFps_fp_TT, testActs, rtypes, names_rTypes)
# Out:
# ID  recall    prec F-score      reaction class
#  0  0.9175  0.9327  0.9250     1.2.1 Aldehyde reductive amination
#  1  0.9812  0.8961  0.9368     1.2.4 Eschweiler-Clarke methylation
#  2  0.9738  0.9582  0.9659     1.2.5 Ketone reductive amination
#  3  0.9613  0.9506  0.9559     1.3.6 Bromo N-arylation
#  4  0.9762  0.9571  0.9666     1.3.7 Chloro N-arylation
#  5  0.9875  0.9753  0.9814     1.3.8 Fluoro N-arylation
#  6  0.8075  0.8568  0.8314     1.6.2 Bromo N-alkylation
#  7  0.7975  0.8999  0.8456     1.6.4 Chloro N-alkylation
#  8  0.7450  0.7286  0.7367     1.6.8 Iodo N-alkylation
#  9  0.9762  0.8707  0.9204     1.7.4 Hydroxy to methoxy
# 10  0.8087  0.6203  0.7021     1.7.6 Methyl esterification
# 11  0.8600  0.8536  0.8568     1.7.7 Mitsunobu aryl ether synthesis
# 12  0.7675  0.9303  0.8411     1.7.9 Williamson ether synthesis
# 13  0.9437  0.9755  0.9593     1.8.5 Thioether synthesis
# 14  0.9150  0.9015  0.9082    10.1.1 Bromination
# 15  0.8450  0.9260  0.8837    10.1.2 Chlorination
# 16  0.9650  0.9290  0.9467    10.1.5 Wohl-Ziegler bromination
# 17  0.9637  0.9961  0.9797    10.2.1 Nitration
# 18  0.6112  0.6839  0.6455    10.4.2 Methylation
# 19  0.9012  0.8472  0.8734     2.1.1 Amide Schotten-Baumann
# 20  0.8950  0.9299  0.9121     2.1.2 Carboxylic acid + amine reaction
# 21  0.9313  0.9751  0.9527     2.1.7 N-acetylation
# 22  0.9862  0.9838  0.9850     2.2.3 Sulfonamide Schotten-Baumann
# 23  0.9912  0.9962  0.9937     2.3.1 Isocyanate + amine reaction
# 24  0.9413  0.8695  0.9040     2.6.1 Ester Schotten-Baumann
# 25  0.4863  0.6742  0.5650     2.6.3 Fischer-Speier esterification
# 26  0.9950  0.9987  0.9969     2.7.2 Sulfonic ester Schotten-Baumann
# 27  0.6212  0.5474  0.5820     3.1.1 Bromo Suzuki coupling
# 28  0.4725  0.5824  0.5217     3.1.5 Bromo Suzuki-type coupling
# 29  0.9700  0.9860  0.9779     3.1.6 Chloro Suzuki-type coupling
# 30  0.9938  0.9962  0.9950     3.3.1 Sonogashira coupling
# 31  0.9387  0.9555  0.9470     3.4.1 Stille reaction
# 32  0.9537  0.9974  0.9751     5.1.1 N-Boc protection
# 33  0.9962  0.9779  0.9870     6.1.1 N-Boc deprotection
# 34  0.9988  0.9988  0.9988     6.1.3 N-Cbz deprotection
# 35  0.9950  0.9815  0.9882     6.1.5 N-Bn deprotection
# 36  0.9975  0.9545  0.9756     6.2.1 CO2H-Et deprotection
# 37  0.9950  0.9815  0.9882     6.2.2 CO2H-Me deprotection
# 38  0.9988  0.9950  0.9969     6.2.3 CO2H-tBu deprotection
# 39  1.0000  0.9938  0.9969     6.3.1 O-Bn deprotection
# 40  0.9800  0.9788  0.9794     6.3.7 Methoxy to hydroxy
# 41  0.9788  0.9911  0.9849     7.1.1 Nitro to amino
# 42  0.9912  0.9351  0.9624     7.2.1 Amide to amine reduction
# 43  0.9875  0.9729  0.9801     7.3.1 Nitrile reduction
# 44  0.9700  0.9676  0.9688     7.9.2 Carboxylic acid to alcohol reduction
# 45  0.9675  0.9567  0.9621     8.1.4 Alcohol to aldehyde oxidation
# 46  0.9688  0.9712  0.9700     8.1.5 Alcohol to ketone oxidation
# 47  0.9800  0.9975  0.9887     8.2.1 Sulfanyl to sulfinyl
# 48  0.8425  0.8686  0.8553     9.1.6 Hydroxy to chloro
# 49  0.9613  0.8120  0.8804     9.3.1 Carboxylic acid to acid chloride
# Mean: 0.91    0.91    0.91

# %%
utilsFunctions.labelled_cmat(cmat_fp_TT,rtypes,figsize=(16,12),labelExtras=names_rTypes)
